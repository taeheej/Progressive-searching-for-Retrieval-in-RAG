# %% [markdown]
# # RAG Benchmark & Optimization

# %% [markdown]
# ## Preparation - Loading dataset

# %% [markdown]
# ### Import

# %%
import os
import gc
import numpy as np
import pandas as pd
import time, pprint, json, re

from sklearn.decomposition import PCA
# import umap
# import faiss
# import hnswlib
from sklearn.neighbors import NearestNeighbors
import plotly.graph_objects as go

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Load Embedding

# %%
import glob

# %%
def load_chunked_embeddings(folder):
    pkl_files = sorted(glob.glob(os.path.join(folder, "gte_Qwen2_7B_instruct_*.pkl")))
    df_list   = []
    for pf in pkl_files:
        df_ch = pd.read_pickle(pf)
        df_list.append(df_ch)
    if not df_list:
        print("No chunk files found in", folder)
        return pd.DataFrame(columns=["text","embedding"])

    df_full = pd.concat(df_list, ignore_index=True)
    return df_full

# %%
def load_questions(pkl_path):

    return pd.read_pickle(pkl_path)

# %%
def load_contexts(csv_path):

    df = pd.read_csv(csv_path, encoding='utf-8')
    return df['context'].tolist()  # or a Series

# %% [markdown]
# ### Dimension Reduction

# %%
def reduce_embeddings(
    dataset_embs,
    question_embs,
    method_name,      # "pca", "truncate_first", "truncate_last", "truncate_four"
    target_dim,
    umap_kwargs=None,
    pca_kwargs=None
):
    if umap_kwargs is None: umap_kwargs = {}
    if pca_kwargs  is None: pca_kwargs  = {}

    method = method_name.lower()
    D = dataset_embs.shape[1]

    # PCA
    if method == "pca":
        pca_model  = PCA(n_components=target_dim, random_state=42, **pca_kwargs)
        dataset_red  = pca_model.fit_transform(dataset_embs)
        question_red = pca_model.transform(question_embs)

    # Truncation: first and last
    elif method == "truncate_first":
        if target_dim > D:
            raise ValueError(f"target_dim {target_dim} > original dim {D}")
        idx          = slice(0, target_dim)
        dataset_red  = dataset_embs[:, idx]
        question_red = question_embs[:, idx]

    elif method == "truncate_last":
        if target_dim > D:
            raise ValueError(f"target_dim {target_dim} > original dim {D}")
        idx          = slice(D - target_dim, D)
        dataset_red  = dataset_embs[:, idx]
        question_red = question_embs[:, idx]

    # Truncation: four‑slice
    elif method == "truncate_four":
        if target_dim > D:
            raise ValueError(f"target_dim {target_dim} > original dim {D}")
        if target_dim % 4 != 0:
            raise ValueError("truncate_four requires target_dim divisible by 4")

        seg  = target_dim // 4                     # width of each slice
        anchors = [0, 0.25, 0.50, 0.75]           # 0%, 25%, 50%, 75%
        cols = np.hstack([
            np.arange(int(a * D), int(a * D) + seg)
            for a in anchors
        ])
        dataset_red  = dataset_embs[:, cols]
        question_red = question_embs[:, cols]

    else:
        raise ValueError(f"Unknown method_name '{method_name}'")

    return dataset_red.astype(np.float32, copy=False), question_red.astype(np.float32, copy=False)

# %% [markdown]
# ### Retrieval Functions

# %%
def knn_search(dataset_embs, question_embs, top_k=1):

    nn = NearestNeighbors(n_neighbors=top_k, algorithm='auto')
    nn.fit(dataset_embs)
    dist, idx = nn.kneighbors(question_embs, n_neighbors=top_k, return_distance=True)
    return idx  # shape (Q, top_k)

# %% [markdown]
# ### Evaluation / Comparison Function

# %%
def evaluate_retrieval(indices, df_dataset, contexts):
    """
    indices: shape (Q,1) from knn or hnsw
    df_dataset: the big dataset with columns [text, embedding], index=0..N-1
    contexts: list of ground truth (the 'correct' text for question i)

    We do an exact match: retrieved_text == contexts[i].
    Returns how many matches or an accuracy count.
    """
    correct = 0
    Q = len(contexts)
    for i in range(Q):
        best_idx = indices[i,0]
        retrieved_text = df_dataset.iloc[best_idx]["text"]
        if retrieved_text == contexts[i]:
            correct += 1
    accuracy = correct / Q
    return accuracy

# %% [markdown]
# ### Complete Process

# %%
def run_complete_experiment_with_time(
    df_dataset,           # DataFrame with [text, embedding], shape (N,2)
    dataset_embs,
    question_embs,
    contexts,
    method_name,
    target_dim,
    do_knn=False,
    do_hnsw=False,
    umap_kwargs=None,
    pca_kwargs=None
):
    # print(f"\n=== {method_name.upper()}  |  dim={target_dim} ===")

    # 2) Dimension reduction
    t0 = time.perf_counter()
    ds_red, qs_red = reduce_embeddings(
        dataset_embs,
        question_embs,
        method_name=method_name,
        target_dim=target_dim,
        umap_kwargs=umap_kwargs,
        pca_kwargs=pca_kwargs
    )
    dt_reduce_sec = time.perf_counter() - t0

    # print(f"Dimension reduction: {dt_reduce_sec:.2f} sec")

    # 3) KNN retrieval
    if do_knn:
        t0 = time.perf_counter()
        idx_knn = knn_search(ds_red, qs_red, top_k=1)
        dt_knn_sec  = time.perf_counter() - t0

        knn_acc = evaluate_retrieval(idx_knn, df_dataset, contexts)
        # print(f"KNN   time: {dt_knn_sec:.2f} sec   |   acc: {knn_acc*100:.2f}%\n")

        knn_accuracy = round(knn_acc*100, 4)

    # 4) HNSW retrieval
    if do_hnsw:
        idx_hnsw, dt_hnsw_build_sec, dt_hnsw_search_sec = hnswlib_search(ds_red, qs_red)
        # dt_hnsw_build_min = dt_hnsw_build_sec / 60
        # dt_hnsw_search_min = dt_hnsw_search_sec / 60
        hnsw_acc = evaluate_retrieval(idx_hnsw, df_dataset, contexts)
        print(f"HNSW Build time: {dt_hnsw_build_sec} sec   |   HNSW Search time: {dt_hnsw_search_sec} sec   |   acc: {hnsw_acc*100:.2f}%\n")
        # print(f"HNSW Accuracy, dim={target_dim}, method={method_name}: {hnsw_acc*100:.4f}%")
        hnsw_accuracy = round(hnsw_acc*100, 4)

    del ds_red, qs_red
    gc.collect()


    return {
        "dt_reduce": round(dt_reduce_sec, 4),
        "knn_accuracy": knn_accuracy if do_knn else None,
        "dt_knn": round(dt_knn_sec, 4) if do_knn else None,
        "hnsw_accuracy": hnsw_accuracy if do_hnsw else None,
        "dt_hnsw_build": round(dt_hnsw_build_sec, 4) if do_hnsw else None,
        "dt_hnsw_search": round(dt_hnsw_search_sec, 4) if do_hnsw else None
    }

# %% [markdown]
# ### Load data

# %%
# dataset_folder = "/content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/MyProject/embeddings/Linq/4096/dataset"
ALIBABANLP_EMB_PATH  = '/content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/MyProject/embeddings/Alibaba_NLP_3584/dataset'
df_dataset = load_chunked_embeddings(ALIBABANLP_EMB_PATH)
print("Dataset loaded:", df_dataset.shape)
# Out:
# Dataset loaded: (1000000, 2)

# %%
QUESTIONS_EMB_PATH = '/content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/MyProject/embeddings/Alibaba_NLP_3584/questions/gte_Qwen2_7B_instruct_questions.pkl'
df_questions = load_questions(QUESTIONS_EMB_PATH)
print("Questions loaded:", df_questions.shape)
# Out:
# Questions loaded: (2470, 2)

# %%
contexts_csv = "/content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/MyProject/qnc/combined/context_final.csv"
contexts = load_contexts(contexts_csv)
print("Contexts loaded:", len(contexts))
# Out:
# Contexts loaded: 2470

# %%
dataset_embs = np.vstack(df_dataset["embedding"].values).astype("float32")
question_embs= np.vstack(df_questions["embedding"].values).astype("float32")

# %%
def plot_accuracy_dicts(acc_dicts: dict, title="Accuracy vs Dimension"):

    # union of all dimensions, sorted high→low
    all_dims = sorted({d for dct in acc_dicts.values() for d in dct}, reverse=True)

    def y_for(label):
        return [acc_dicts[label].get(d, None) for d in all_dims]

    fig = go.Figure()
    marker_cycle = ["circle", "square", "triangle-up", "diamond", "cross"]
    for i, label in enumerate(acc_dicts):
        y_vals = y_for(label)
        fig.add_trace(
            go.Scatter(
                x=all_dims,
                y=y_vals,
                mode="markers+lines",
                marker=dict(symbol=marker_cycle[i % len(marker_cycle)], size=8),
                name=label,
                text=[
                    f"Dim {d}<br>{label}<br>{acc:.2f}%" if acc is not None
                    else f"Dim {d}<br>{label}<br>(missing)"
                    for d, acc in zip(all_dims, y_vals)
                ],
                hoverinfo="text",
                connectgaps=True
            )
        )

    fig.update_layout(
        title=title,
        xaxis_title="Embedding Dimension",
        yaxis_title="Accuracy (%)",
        yaxis=dict(range=[0, 100]),
        template="plotly_white",
        hovermode="closest",
        legend_title="Method"
    )
    fig.show()

# %% [markdown]
# ## Preparation - Progressive KNN

# %%
def evaluate_retrieval(indices, df_dataset, contexts):

    if indices.ndim == 2:
        indices = indices.ravel()          # (Q,)
    correct = 0
    for i, row_id in enumerate(indices):
        if df_dataset.iloc[row_id]["text"] == contexts[i]:
            correct += 1
    return correct / len(contexts)

# %%
from typing import List, Dict

# %%
def evaluate_exact(indices, df_dataset, contexts):
    hits = sum(df_dataset.iloc[idx]["text"] == ctx
               for idx, ctx in zip(indices, contexts))
    return hits / len(contexts)

# %%
def progressive_knn_sklearn(
        ds_embs: np.ndarray,
        qs_embs: np.ndarray,
        df_dataset, contexts,
        algorithm = "brute",
        start_dim: int      = 64,
        start_k: int        = 1000,
        max_dim: int        = 512,
        step_factor: int    = 2,      # dim *= step_factor each loop
        step_k: int         = 2,      # how much k we keep, e.g. 2 -> k = k // step_k
        step_add: int       = None,   # add to dim
        verbose: bool       = True):

    if ((step_add is not None) and (step_factor is not None)) or ((step_add is None) and (step_factor is None)):
        raise ValueError("Choose either step_add or step factor")
    if step_add is None and step_factor <= 1:
        raise ValueError("step_factor must be > 1 when step_add is None")

    N, D = ds_embs.shape
    Q    = qs_embs.shape[0]

    def build_index(mat):
        # brute-force
        # return NearestNeighbors(n_neighbors=1, algorithm="brute", metric="euclidean").fit(mat)
        # auto
        return NearestNeighbors(n_neighbors=1, algorithm=algorithm, metric="euclidean").fit(mat)

    # --------------------------------------------------------
    # 1) initial global search on first start_dim dimensions
    t0 = time.perf_counter()
    index0 = build_index(ds_embs[:, :start_dim])
    _, I = index0.kneighbors(qs_embs[:, :start_dim], n_neighbors=start_k)
    pools = I.copy()                 # shape (Q, start_k)
    cand_set = np.unique(I.ravel())
    t_init = time.perf_counter() - t0
    if verbose:
        print(f"[init 0:{start_dim}] unique rows = {cand_set.size:,}")


    dim = start_dim
    k    = start_k
    t_slices = 0.0

    # ----------------------------------------
    # 2) loop
    while dim < max_dim:
        if step_add is None:
            new_dim = min(dim * step_factor, max_dim)
        else:
            new_dim = min(dim + step_add, max_dim)

        if new_dim >= max_dim:
            break

        dim = new_dim
        k   = max(1, k // step_k)          # halve pool size

        if verbose:
            print(f"[slice 0:{dim}] k={k}")

        t0 = time.perf_counter()
        # build index on current candidate rows
        cand_mat = ds_embs[cand_set][:, :dim]
        idx_local = build_index(cand_mat)

        # query all questions at once
        _, Iq = idx_local.kneighbors(qs_embs[:, :dim], n_neighbors=k)

        # map local → global row IDs
        pools = cand_set[Iq]

        # union of all rows for next round
        cand_set = np.unique(pools.ravel())
        t_slices += time.perf_counter() - t0

        if verbose:
            print(f"           candidates → {cand_set.size:,}")

    # ------------------------------------------------
    # 3) final 1-NN on remaining rows (0:max_dim)
    t0 = time.perf_counter()
    final_idx = build_index(ds_embs[cand_set][:, :max_dim])
    _, I_final = final_idx.kneighbors(qs_embs[:, :max_dim], n_neighbors=1)
    t_final = time.perf_counter() - t0
    row_ids = cand_set[I_final.ravel()]

    # 4) evaluate
    acc_pct = round(100 * evaluate_exact(row_ids, df_dataset, contexts), 4)
    return {
        "accuracy_pct": acc_pct,
        "final_pool"  : int(cand_set.size),
        "t_total_s": round(t_init+t_slices+t_final, 2)
    }

# %% [markdown]
# ## Experiment

# %%
drive_root = "/content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System"

def save_json(obj, filename):
    path = f"{drive_root}/{filename}"
    with open(path, "w") as f:
        # json.dump(obj, f, indent=2)
        json.dump({str(k): v for k,v in obj.items()}, f, indent=2)
    print("✔  saved →", path)

# %% [markdown]
# ### Truncation and KNN

# %%
truncate_dims=[3584, 3072, 2048, 1024, 512, 504, 496, 488, 480, 472, 464, 456, 448, 440, 432, 424, 416, 408, 400, 392, 384, 376, 368, 360, 352, 344, 336, 328, 320, 312, 304, 296, 288, 280, 272, 264, 256, 248, 240, 232, 224, 216, 208, 200, 192, 184, 176, 168, 160, 152, 144, 136, 128, 120, 112, 104, 96, 88, 80, 72, 64, 56, 48, 40, 32, 16]
knn_results = {}

# %% [markdown]
# #### Initial Run

# %%
for dim in truncate_dims:
    times     = []
    accs      = []

    for run in range(10):
        res = run_complete_experiment_with_time(
            df_dataset    = df_dataset,
            dataset_embs  = dataset_embs,
            question_embs = question_embs,
            contexts      = contexts,
            method_name   = "truncate_first",
            target_dim    = dim,
            do_knn        = True,
            do_hnsw       = False
        )
        times.append(res["dt_knn"])
        accs.append(res["knn_accuracy"])
        gc.collect()

    # -------- verify accuracy constant ------------
    uniq_acc = set(accs)
    if len(uniq_acc) != 1:
        print(f"accuracy drift at {dim}d → {uniq_acc}")
    acc_pct = round(accs[0], 4)

    # -------- median timing -----------------------
    median_time = round(float(np.median(times)), 4)

    print(f"Dim {dim:4d} | 10 runs (s): {sorted(round(t,4) for t in times)} "
          f"→ median={median_time:.4f}s | acc={acc_pct:.4f}%")

    knn_results[dim] = {
        "accuracy_pct" : acc_pct,
        "median_time_s": median_time,
        # "times_s"      : [round(t,4) for t in times]   # full trace if needed
    }

print("\n=== Summary (median time) ===")
for d in sorted(knn_results, reverse=True):
    r = knn_results[d]
    print(f"{d:4d} d  |  {r['accuracy_pct']:7.4f}%  |  {r['median_time_s']:8.4f}s")
# Out:
# Dim 3584 | 10 runs (s): [98.5961, 98.801, 99.1897, 99.2253, 99.336, 99.3803, 100.0219, 100.3155, 100.4691, 100.9872] → median=99.3581s | acc=95.0202%
# Dim 3072 | 10 runs (s): [86.0599, 86.7163, 86.8852, 87.2316, 87.4144, 87.5882, 87.6553, 87.7125, 87.7228, 88.1838] → median=87.5013s | acc=94.9798%
# Dim 2048 | 10 runs (s): [56.997, 57.2135, 57.3249, 57.4445, 57.4722, 57.5043, 57.5077, 57.748, 57.7928, 58.0219] → median=57.4883s | acc=94.8178%
# Dim 1024 | 10 runs (s): [29.5732, 29.5801, 29.6115, 29.6506, 29.6599, 29.7328, 29.8109, 29.849, 29.8504, 29.8842] → median=29.6964s | acc=94.4939%
# Dim  512 | 10 runs (s): [16.2359, 16.2738, 16.3007, 16.4075, 16.432, 16.4523, 16.4963, 16.5404, 16.5588, 16.5724] → median=16.4421s | acc=93.8057%
# Dim  504 | 10 runs (s): [15.6833, 15.7181, 15.7187, 15.747, 15.7502, 15.7692, 15.7708, 15.7761, 15.7881, 15.9188] → median=15.7597s | acc=93.8866%
# Dim  496 | 10 runs (s): [15.4512, 15.4717, 15.4963, 15.5499, 15.6168, 15.6298, 15.7222, 15.7654, 15.8014, 15.8141] → median=15.6233s | acc=93.8057%
# Dim  488 | 10 runs (s): [15.2037, 15.2578, 15.2668, 15.2745, 15.3309, 15.3498, 15.4306, 15.4317, 15.5069, 15.5605] → median=15.3404s | acc=93.7652%
# Dim  480 | 10 runs (s): [14.8889, 14.8997, 14.9975, 15.0141, 15.0499, 15.0574, 15.0699, 15.1098, 15.1467, 15.1985] → median=15.0536s | acc=93.7247%
# Dim  472 | 10 runs (s): [14.5879, 14.6479, 14.6859, 14.7607, 14.7785, 14.8168, 14.8425, 14.8713, 14.89, 15.0226] → median=14.7977s | acc=93.7652%
# Dim  464 | 10 runs (s): [14.5497, 14.5882, 14.6482, 14.6722, 14.687, 14.7447, 14.7479, 14.8413, 14.9796, 15.1213] → median=14.7158s | acc=93.8057%
# Dim  456 | 10 runs (s): [14.4664, 14.4816, 14.4982, 14.5535, 14.5573, 14.581, 14.6309, 14.6627, 14.6728, 14.6753] → median=14.5692s | acc=93.7652%
# Dim  448 | 10 runs (s): [14.2048, 14.2834, 14.3134, 14.3624, 14.3937, 14.4, 14.4168, 14.4486, 14.4645, 14.4846] → median=14.3969s | acc=93.6842%
# Dim  440 | 10 runs (s): [14.0753, 14.0891, 14.1456, 14.1815, 14.2217, 14.2545, 14.2664, 14.2836, 14.2958, 14.5102] → median=14.2381s | acc=93.5628%
# Dim  432 | 10 runs (s): [13.8269, 13.8611, 13.8906, 13.9279, 13.931, 13.9546, 13.9628, 14.0422, 14.0854, 14.351] → median=13.9428s | acc=93.5223%
# Dim  424 | 10 runs (s): [13.7673, 13.875, 13.9283, 13.9464, 13.9882, 14.021, 14.0299, 14.041, 14.0591, 14.0683] → median=14.0046s | acc=93.6032%
# Dim  416 | 10 runs (s): [13.5113, 13.5763, 13.5872, 13.6636, 13.6711, 13.6742, 13.715, 13.7419, 13.7753, 13.8312] → median=13.6727s | acc=93.6032%
# Dim  408 | 10 runs (s): [13.4591, 13.4819, 13.486, 13.5092, 13.5678, 13.5779, 13.5953, 13.6078, 13.6158, 13.6311] → median=13.5728s | acc=93.5628%
# Dim  400 | 10 runs (s): [13.2636, 13.2919, 13.3339, 13.3351, 13.3786, 13.4024, 13.4073, 13.429, 13.4519, 13.5268] → median=13.3905s | acc=93.6032%
# Dim  392 | 10 runs (s): [13.0054, 13.0158, 13.0221, 13.043, 13.0485, 13.058, 13.0715, 13.0716, 13.1578, 13.1924] → median=13.0533s | acc=93.5223%
# Dim  384 | 10 runs (s): [12.6727, 12.6807, 12.7358, 12.7405, 12.8385, 12.8441, 12.88, 12.9338, 12.9409, 13.0092] → median=12.8413s | acc=93.4008%
# Dim  376 | 10 runs (s): [12.2072, 12.3001, 12.3019, 12.3514, 12.4022, 12.4283, 12.4582, 12.5006, 12.5166, 12.6906] → median=12.4153s | acc=93.2794%
# Dim  368 | 10 runs (s): [11.9974, 12.003, 12.059, 12.0842, 12.0937, 12.1033, 12.1038, 12.1167, 12.1689, 12.1987] → median=12.0985s | acc=93.2794%
# Dim  360 | 10 runs (s): [11.7829, 11.8199, 11.822, 11.8401, 11.9608, 11.9768, 12.0176, 12.077, 12.0907, 12.1685] → median=11.9688s | acc=93.2389%
# Dim  352 | 10 runs (s): [11.6514, 11.6531, 11.6847, 11.6893, 11.6976, 11.7434, 11.7986, 11.8156, 11.8367, 11.9119] → median=11.7205s | acc=93.1579%
# Dim  344 | 10 runs (s): [11.3963, 11.4253, 11.4263, 11.4331, 11.4962, 11.538, 11.5711, 11.5807, 11.62, 11.6891] → median=11.5171s | acc=92.9555%
# Dim  336 | 10 runs (s): [11.1637, 11.238, 11.3026, 11.3328, 11.368, 11.3922, 11.4234, 11.4921, 11.5174, 11.5184] → median=11.3801s | acc=92.8745%
# Dim  328 | 10 runs (s): [11.0132, 11.1046, 11.1064, 11.1222, 11.1414, 11.1721, 11.2067, 11.2515, 11.2886, 11.3223] → median=11.1568s | acc=92.8745%
# Dim  320 | 10 runs (s): [10.7636, 10.7952, 10.8004, 10.8235, 10.8795, 10.8833, 10.9048, 10.9172, 11.1553, 11.1705] → median=10.8814s | acc=92.7126%
# Dim  312 | 10 runs (s): [10.4112, 10.6056, 10.6257, 10.6973, 10.7043, 10.7789, 10.801, 10.8165, 10.8248, 10.8853] → median=10.7416s | acc=92.5911%
# Dim  304 | 10 runs (s): [10.3105, 10.3392, 10.462, 10.4622, 10.5315, 10.5439, 10.5689, 10.5969, 10.6186, 10.9144] → median=10.5377s | acc=92.3887%
# Dim  296 | 10 runs (s): [10.1995, 10.245, 10.3828, 10.3868, 10.3947, 10.442, 10.4581, 10.4799, 10.4836, 10.5146] → median=10.4184s | acc=92.5506%
# Dim  288 | 10 runs (s): [10.0292, 10.05, 10.0658, 10.1435, 10.1846, 10.1865, 10.2795, 10.2816, 10.337, 10.3875] → median=10.1855s | acc=93.0769%
# Dim  280 | 10 runs (s): [9.6767, 9.8797, 9.9197, 9.9205, 9.962, 9.9644, 10.063, 10.0676, 10.1105, 10.1476] → median=9.9632s | acc=93.1579%
# Dim  272 | 10 runs (s): [9.6072, 9.6148, 9.7516, 9.7561, 9.7765, 9.8097, 9.8101, 9.8265, 9.8677, 9.878] → median=9.7931s | acc=92.9555%
# Dim  264 | 10 runs (s): [9.3566, 9.4343, 9.5161, 9.5223, 9.5341, 9.5529, 9.5867, 9.6196, 9.6285, 9.7512] → median=9.5435s | acc=93.0364%
# Dim  256 | 10 runs (s): [9.2572, 9.3069, 9.3268, 9.3443, 9.366, 9.4019, 9.427, 9.5305, 9.5872, 9.6359] → median=9.3839s | acc=92.7935%
# Dim  248 | 10 runs (s): [9.032, 9.0337, 9.0734, 9.0907, 9.1373, 9.1381, 9.1454, 9.1744, 9.2321, 9.2636] → median=9.1377s | acc=92.8745%
# Dim  240 | 10 runs (s): [8.8112, 8.8638, 8.8775, 8.8779, 8.8955, 8.943, 8.9608, 8.9784, 9.0025, 9.1093] → median=8.9192s | acc=92.5911%
# Dim  232 | 10 runs (s): [8.4606, 8.4638, 8.5028, 8.507, 8.5726, 8.5786, 8.6164, 8.6218, 8.635, 8.6746] → median=8.5756s | acc=92.4291%
# Dim  224 | 10 runs (s): [8.4144, 8.4225, 8.4747, 8.5008, 8.516, 8.5539, 8.6318, 8.6637, 8.6835, 8.7037] → median=8.5350s | acc=92.2267%
# Dim  216 | 10 runs (s): [8.0706, 8.1247, 8.172, 8.188, 8.1889, 8.2083, 8.2097, 8.3105, 8.3378, 8.3743] → median=8.1986s | acc=91.9838%
# Dim  208 | 10 runs (s): [7.7105, 7.7788, 7.8385, 7.9352, 7.9647, 7.9821, 7.9951, 8.0476, 8.0731, 8.0871] → median=7.9734s | acc=91.8623%

# %% [markdown]
# #### Continueous run

# %%
log_text = """
Dim 3584 | 10 runs (s): [98.5961, 98.801, 99.1897, 99.2253, 99.336, 99.3803, 100.0219, 100.3155, 100.4691, 100.9872] → median=99.3581s | acc=95.0202%
Dim 3072 | 10 runs (s): [86.0599, 86.7163, 86.8852, 87.2316, 87.4144, 87.5882, 87.6553, 87.7125, 87.7228, 88.1838] → median=87.5013s | acc=94.9798%
Dim 2048 | 10 runs (s): [56.997, 57.2135, 57.3249, 57.4445, 57.4722, 57.5043, 57.5077, 57.748, 57.7928, 58.0219] → median=57.4883s | acc=94.8178%
Dim 1024 | 10 runs (s): [29.5732, 29.5801, 29.6115, 29.6506, 29.6599, 29.7328, 29.8109, 29.849, 29.8504, 29.8842] → median=29.6964s | acc=94.4939%
Dim  512 | 10 runs (s): [16.2359, 16.2738, 16.3007, 16.4075, 16.432, 16.4523, 16.4963, 16.5404, 16.5588, 16.5724] → median=16.4421s | acc=93.8057%
Dim  504 | 10 runs (s): [15.6833, 15.7181, 15.7187, 15.747, 15.7502, 15.7692, 15.7708, 15.7761, 15.7881, 15.9188] → median=15.7597s | acc=93.8866%
Dim  496 | 10 runs (s): [15.4512, 15.4717, 15.4963, 15.5499, 15.6168, 15.6298, 15.7222, 15.7654, 15.8014, 15.8141] → median=15.6233s | acc=93.8057%
Dim  488 | 10 runs (s): [15.2037, 15.2578, 15.2668, 15.2745, 15.3309, 15.3498, 15.4306, 15.4317, 15.5069, 15.5605] → median=15.3404s | acc=93.7652%
Dim  480 | 10 runs (s): [14.8889, 14.8997, 14.9975, 15.0141, 15.0499, 15.0574, 15.0699, 15.1098, 15.1467, 15.1985] → median=15.0536s | acc=93.7247%
Dim  472 | 10 runs (s): [14.5879, 14.6479, 14.6859, 14.7607, 14.7785, 14.8168, 14.8425, 14.8713, 14.89, 15.0226] → median=14.7977s | acc=93.7652%
Dim  464 | 10 runs (s): [14.5497, 14.5882, 14.6482, 14.6722, 14.687, 14.7447, 14.7479, 14.8413, 14.9796, 15.1213] → median=14.7158s | acc=93.8057%
Dim  456 | 10 runs (s): [14.4664, 14.4816, 14.4982, 14.5535, 14.5573, 14.581, 14.6309, 14.6627, 14.6728, 14.6753] → median=14.5692s | acc=93.7652%
Dim  448 | 10 runs (s): [14.2048, 14.2834, 14.3134, 14.3624, 14.3937, 14.4, 14.4168, 14.4486, 14.4645, 14.4846] → median=14.3969s | acc=93.6842%
Dim  440 | 10 runs (s): [14.0753, 14.0891, 14.1456, 14.1815, 14.2217, 14.2545, 14.2664, 14.2836, 14.2958, 14.5102] → median=14.2381s | acc=93.5628%
Dim  432 | 10 runs (s): [13.8269, 13.8611, 13.8906, 13.9279, 13.931, 13.9546, 13.9628, 14.0422, 14.0854, 14.351] → median=13.9428s | acc=93.5223%
Dim  424 | 10 runs (s): [13.7673, 13.875, 13.9283, 13.9464, 13.9882, 14.021, 14.0299, 14.041, 14.0591, 14.0683] → median=14.0046s | acc=93.6032%
Dim  416 | 10 runs (s): [13.5113, 13.5763, 13.5872, 13.6636, 13.6711, 13.6742, 13.715, 13.7419, 13.7753, 13.8312] → median=13.6727s | acc=93.6032%
Dim  408 | 10 runs (s): [13.4591, 13.4819, 13.486, 13.5092, 13.5678, 13.5779, 13.5953, 13.6078, 13.6158, 13.6311] → median=13.5728s | acc=93.5628%
Dim  400 | 10 runs (s): [13.2636, 13.2919, 13.3339, 13.3351, 13.3786, 13.4024, 13.4073, 13.429, 13.4519, 13.5268] → median=13.3905s | acc=93.6032%
Dim  392 | 10 runs (s): [13.0054, 13.0158, 13.0221, 13.043, 13.0485, 13.058, 13.0715, 13.0716, 13.1578, 13.1924] → median=13.0533s | acc=93.5223%
Dim  384 | 10 runs (s): [12.6727, 12.6807, 12.7358, 12.7405, 12.8385, 12.8441, 12.88, 12.9338, 12.9409, 13.0092] → median=12.8413s | acc=93.4008%
Dim  376 | 10 runs (s): [12.2072, 12.3001, 12.3019, 12.3514, 12.4022, 12.4283, 12.4582, 12.5006, 12.5166, 12.6906] → median=12.4153s | acc=93.2794%
Dim  368 | 10 runs (s): [11.9974, 12.003, 12.059, 12.0842, 12.0937, 12.1033, 12.1038, 12.1167, 12.1689, 12.1987] → median=12.0985s | acc=93.2794%
Dim  360 | 10 runs (s): [11.7829, 11.8199, 11.822, 11.8401, 11.9608, 11.9768, 12.0176, 12.077, 12.0907, 12.1685] → median=11.9688s | acc=93.2389%
Dim  352 | 10 runs (s): [11.6514, 11.6531, 11.6847, 11.6893, 11.6976, 11.7434, 11.7986, 11.8156, 11.8367, 11.9119] → median=11.7205s | acc=93.1579%
Dim  344 | 10 runs (s): [11.3963, 11.4253, 11.4263, 11.4331, 11.4962, 11.538, 11.5711, 11.5807, 11.62, 11.6891] → median=11.5171s | acc=92.9555%
Dim  336 | 10 runs (s): [11.1637, 11.238, 11.3026, 11.3328, 11.368, 11.3922, 11.4234, 11.4921, 11.5174, 11.5184] → median=11.3801s | acc=92.8745%
Dim  328 | 10 runs (s): [11.0132, 11.1046, 11.1064, 11.1222, 11.1414, 11.1721, 11.2067, 11.2515, 11.2886, 11.3223] → median=11.1568s | acc=92.8745%
Dim  320 | 10 runs (s): [10.7636, 10.7952, 10.8004, 10.8235, 10.8795, 10.8833, 10.9048, 10.9172, 11.1553, 11.1705] → median=10.8814s | acc=92.7126%
Dim  312 | 10 runs (s): [10.4112, 10.6056, 10.6257, 10.6973, 10.7043, 10.7789, 10.801, 10.8165, 10.8248, 10.8853] → median=10.7416s | acc=92.5911%
Dim  304 | 10 runs (s): [10.3105, 10.3392, 10.462, 10.4622, 10.5315, 10.5439, 10.5689, 10.5969, 10.6186, 10.9144] → median=10.5377s | acc=92.3887%
Dim  296 | 10 runs (s): [10.1995, 10.245, 10.3828, 10.3868, 10.3947, 10.442, 10.4581, 10.4799, 10.4836, 10.5146] → median=10.4184s | acc=92.5506%
Dim  288 | 10 runs (s): [10.0292, 10.05, 10.0658, 10.1435, 10.1846, 10.1865, 10.2795, 10.2816, 10.337, 10.3875] → median=10.1855s | acc=93.0769%
Dim  280 | 10 runs (s): [9.6767, 9.8797, 9.9197, 9.9205, 9.962, 9.9644, 10.063, 10.0676, 10.1105, 10.1476] → median=9.9632s | acc=93.1579%
Dim  272 | 10 runs (s): [9.6072, 9.6148, 9.7516, 9.7561, 9.7765, 9.8097, 9.8101, 9.8265, 9.8677, 9.878] → median=9.7931s | acc=92.9555%
Dim  264 | 10 runs (s): [9.3566, 9.4343, 9.5161, 9.5223, 9.5341, 9.5529, 9.5867, 9.6196, 9.6285, 9.7512] → median=9.5435s | acc=93.0364%
Dim  256 | 10 runs (s): [9.2572, 9.3069, 9.3268, 9.3443, 9.366, 9.4019, 9.427, 9.5305, 9.5872, 9.6359] → median=9.3839s | acc=92.7935%
Dim  248 | 10 runs (s): [9.032, 9.0337, 9.0734, 9.0907, 9.1373, 9.1381, 9.1454, 9.1744, 9.2321, 9.2636] → median=9.1377s | acc=92.8745%
Dim  240 | 10 runs (s): [8.8112, 8.8638, 8.8775, 8.8779, 8.8955, 8.943, 8.9608, 8.9784, 9.0025, 9.1093] → median=8.9192s | acc=92.5911%
Dim  232 | 10 runs (s): [8.4606, 8.4638, 8.5028, 8.507, 8.5726, 8.5786, 8.6164, 8.6218, 8.635, 8.6746] → median=8.5756s | acc=92.4291%
Dim  224 | 10 runs (s): [8.4144, 8.4225, 8.4747, 8.5008, 8.516, 8.5539, 8.6318, 8.6637, 8.6835, 8.7037] → median=8.5350s | acc=92.2267%
Dim  216 | 10 runs (s): [8.0706, 8.1247, 8.172, 8.188, 8.1889, 8.2083, 8.2097, 8.3105, 8.3378, 8.3743] → median=8.1986s | acc=91.9838%
Dim  208 | 10 runs (s): [7.7105, 7.7788, 7.8385, 7.9352, 7.9647, 7.9821, 7.9951, 8.0476, 8.0731, 8.0871] → median=7.9734s | acc=91.8623%
"""

# %%
pattern = re.compile(
    r"Dim\s+(\d+)\s+\|.*?median=([\d\.]+)s\s+\|\s+acc=([\d\.]+)"
)

# %%
knn_results = {}
for dim, t, acc in pattern.findall(log_text):
    knn_results[int(dim)] = {
        "accuracy_pct" : round(float(acc), 4),
        "median_time_s": round(float(t),   4)
    }

print("Recovered ↓"); pprint.pprint(knn_results)
# Out:
# Recovered ↓
# {208: {'accuracy_pct': 91.8623, 'median_time_s': 7.9734},
#  216: {'accuracy_pct': 91.9838, 'median_time_s': 8.1986},
#  224: {'accuracy_pct': 92.2267, 'median_time_s': 8.535},
#  232: {'accuracy_pct': 92.4291, 'median_time_s': 8.5756},
#  240: {'accuracy_pct': 92.5911, 'median_time_s': 8.9192},
#  248: {'accuracy_pct': 92.8745, 'median_time_s': 9.1377},
#  256: {'accuracy_pct': 92.7935, 'median_time_s': 9.3839},
#  264: {'accuracy_pct': 93.0364, 'median_time_s': 9.5435},
#  272: {'accuracy_pct': 92.9555, 'median_time_s': 9.7931},
#  280: {'accuracy_pct': 93.1579, 'median_time_s': 9.9632},
#  288: {'accuracy_pct': 93.0769, 'median_time_s': 10.1855},
#  296: {'accuracy_pct': 92.5506, 'median_time_s': 10.4184},
#  304: {'accuracy_pct': 92.3887, 'median_time_s': 10.5377},
#  312: {'accuracy_pct': 92.5911, 'median_time_s': 10.7416},
#  320: {'accuracy_pct': 92.7126, 'median_time_s': 10.8814},
#  328: {'accuracy_pct': 92.8745, 'median_time_s': 11.1568},
#  336: {'accuracy_pct': 92.8745, 'median_time_s': 11.3801},
#  344: {'accuracy_pct': 92.9555, 'median_time_s': 11.5171},
#  352: {'accuracy_pct': 93.1579, 'median_time_s': 11.7205},
#  360: {'accuracy_pct': 93.2389, 'median_time_s': 11.9688},
#  368: {'accuracy_pct': 93.2794, 'median_time_s': 12.0985},
#  376: {'accuracy_pct': 93.2794, 'median_time_s': 12.4153},
#  384: {'accuracy_pct': 93.4008, 'median_time_s': 12.8413},
#  392: {'accuracy_pct': 93.5223, 'median_time_s': 13.0533},
#  400: {'accuracy_pct': 93.6032, 'median_time_s': 13.3905},
#  408: {'accuracy_pct': 93.5628, 'median_time_s': 13.5728},
#  416: {'accuracy_pct': 93.6032, 'median_time_s': 13.6727},
#  424: {'accuracy_pct': 93.6032, 'median_time_s': 14.0046},
#  432: {'accuracy_pct': 93.5223, 'median_time_s': 13.9428},
#  440: {'accuracy_pct': 93.5628, 'median_time_s': 14.2381},
#  448: {'accuracy_pct': 93.6842, 'median_time_s': 14.3969},
#  456: {'accuracy_pct': 93.7652, 'median_time_s': 14.5692},
#  464: {'accuracy_pct': 93.8057, 'median_time_s': 14.7158},
#  472: {'accuracy_pct': 93.7652, 'median_time_s': 14.7977},
#  480: {'accuracy_pct': 93.7247, 'median_time_s': 15.0536},
#  488: {'accuracy_pct': 93.7652, 'median_time_s': 15.3404},
#  496: {'accuracy_pct': 93.8057, 'median_time_s': 15.6233},
#  504: {'accuracy_pct': 93.8866, 'median_time_s': 15.7597},
#  512: {'accuracy_pct': 93.8057, 'median_time_s': 16.4421},
#  1024: {'accuracy_pct': 94.4939, 'median_time_s': 29.6964},
#  2048: {'accuracy_pct': 94.8178, 'median_time_s': 57.4883},
#  3072: {'accuracy_pct': 94.9798, 'median_time_s': 87.5013},
#  3584: {'accuracy_pct': 95.0202, 'median_time_s': 99.3581}}

# %%
done_dims = set(knn_results)

for dim in truncate_dims:
    if dim in done_dims:
        continue

    times     = []
    accs      = []

    for run in range(10):
        res = run_complete_experiment_with_time(
            df_dataset    = df_dataset,
            dataset_embs  = dataset_embs,
            question_embs = question_embs,
            contexts      = contexts,
            method_name   = "truncate_first",
            target_dim    = dim,
            do_knn        = True,
            do_hnsw       = False
        )
        times.append(res["dt_knn"])
        accs.append(res["knn_accuracy"])
        gc.collect()

    # -------- verify accuracy constant ------------
    uniq_acc = set(accs)
    if len(uniq_acc) != 1:
        print(f"accuracy drift at {dim}d → {uniq_acc}")
    acc_pct = round(accs[0], 4)

    # -------- median timing -----------------------
    median_time = round(float(np.median(times)), 4)

    print(f"Dim {dim:4d} | 10 runs (s): {sorted(round(t,4) for t in times)} "
          f"→ median={median_time:.4f}s | acc={acc_pct:.4f}%")

    knn_results[dim] = {
        "accuracy_pct" : acc_pct,
        "median_time_s": median_time,
        # "times_s"      : [round(t,4) for t in times]   # full trace if needed
    }

print("\n=== Summary (median time) ===")
for d in sorted(knn_results, reverse=True):
    r = knn_results[d]
    print(f"{d:4d} d  |  {r['accuracy_pct']:7.4f}%  |  {r['median_time_s']:8.4f}s")
# Out:
# Dim  200 | 10 runs (s): [7.5162, 7.5172, 7.5621, 7.6292, 7.6578, 7.7263, 7.7572, 7.7621, 7.7914, 7.8664] → median=7.6921s | acc=91.7409%
# Dim  192 | 10 runs (s): [7.1926, 7.2628, 7.3883, 7.4155, 7.443, 7.4486, 7.4799, 7.5248, 7.5528, 7.6066] → median=7.4458s | acc=91.5789%
# Dim  184 | 10 runs (s): [7.0385, 7.0756, 7.1119, 7.1401, 7.2211, 7.2404, 7.2559, 7.29, 7.3343, 7.358] → median=7.2308s | acc=91.3765%
# Dim  176 | 10 runs (s): [6.8027, 6.8515, 6.8629, 6.9009, 6.9367, 6.9654, 7.0106, 7.1342, 7.1767, 7.2002] → median=6.9511s | acc=91.0526%
# Dim  168 | 10 runs (s): [6.5749, 6.6374, 6.7385, 6.8073, 6.8434, 6.8462, 6.8656, 6.9242, 6.9403, 7.0034] → median=6.8448s | acc=90.8502%
# Dim  160 | 10 runs (s): [6.3796, 6.3903, 6.4692, 6.5586, 6.5947, 6.6076, 6.6183, 6.6364, 6.6504, 6.6659] → median=6.6011s | acc=90.6073%
# Dim  152 | 10 runs (s): [6.1534, 6.2522, 6.2751, 6.29, 6.3126, 6.3203, 6.4021, 6.4164, 6.4816, 6.4902] → median=6.3164s | acc=90.0810%
# Dim  144 | 10 runs (s): [5.9818, 5.9945, 6.0303, 6.0516, 6.0932, 6.1331, 6.1613, 6.1699, 6.1891, 6.2314] → median=6.1132s | acc=89.6356%
# Dim  136 | 10 runs (s): [5.69, 5.8006, 5.8142, 5.8154, 5.8595, 5.925, 5.982, 6.0004, 6.0071, 6.0567] → median=5.8922s | acc=89.5547%
# Dim  128 | 10 runs (s): [5.5327, 5.6011, 5.6682, 5.7003, 5.7041, 5.7149, 5.732, 5.7321, 5.7993, 5.8707] → median=5.7095s | acc=88.7854%
# Dim  120 | 10 runs (s): [5.3449, 5.4204, 5.4283, 5.4804, 5.4853, 5.4901, 5.5026, 5.5337, 5.5683, 5.5696] → median=5.4877s | acc=88.3806%
# Dim  112 | 10 runs (s): [5.055, 5.1274, 5.1379, 5.157, 5.1611, 5.1945, 5.2121, 5.3329, 5.3431, 5.3776] → median=5.1778s | acc=87.8543%
# Dim  104 | 10 runs (s): [4.8725, 4.8747, 4.9487, 4.9816, 5.0099, 5.0367, 5.0371, 5.0483, 5.0878, 5.125] → median=5.0233s | acc=86.5587%
# Dim   96 | 10 runs (s): [4.6632, 4.7289, 4.767, 4.7676, 4.8172, 4.8478, 4.9098, 4.9213, 4.9663, 4.981] → median=4.8325s | acc=84.9798%
# Dim   88 | 10 runs (s): [4.4097, 4.4478, 4.4755, 4.519, 4.5232, 4.5749, 4.603, 4.6149, 4.6475, 4.719] → median=4.5491s | acc=83.1579%
# Dim   80 | 10 runs (s): [4.2561, 4.2623, 4.2722, 4.2876, 4.3033, 4.3173, 4.3301, 4.3686, 4.4245, 4.4565] → median=4.3103s | acc=80.5263%
# Dim   72 | 10 runs (s): [4.0396, 4.0459, 4.0978, 4.11, 4.1525, 4.1835, 4.1933, 4.2443, 4.2844, 4.3416] → median=4.1680s | acc=76.8826%
# Dim   64 | 10 runs (s): [3.764, 3.7829, 3.7847, 3.796, 3.8129, 3.8559, 3.8573, 3.8738, 3.9262, 3.9501] → median=3.8344s | acc=78.4211%
# Dim   56 | 10 runs (s): [3.5683, 3.6047, 3.6214, 3.6288, 3.6466, 3.6706, 3.6849, 3.6988, 3.7108, 3.7294] → median=3.6586s | acc=71.7814%
# Dim   48 | 10 runs (s): [3.359, 3.3762, 3.3864, 3.4258, 3.4323, 3.4488, 3.45, 3.4502, 3.4753, 3.4895] → median=3.4405s | acc=62.7126%
# Dim   40 | 10 runs (s): [3.1426, 3.1548, 3.172, 3.1912, 3.1963, 3.2056, 3.2168, 3.2576, 3.2768, 3.2978] → median=3.2009s | acc=50.6478%
# Dim   32 | 10 runs (s): [2.9344, 2.9699, 2.9701, 2.9891, 3.0057, 3.0205, 3.0511, 3.0553, 3.068, 3.098] → median=3.0131s | acc=39.5547%
# Dim   16 | 10 runs (s): [2.5767, 2.6365, 2.6433, 2.6489, 2.6543, 2.7358, 2.7571, 2.7658, 2.7804, 2.8248] → median=2.6951s | acc=6.5587%
#
# === Summary (median time) ===
# 3584 d  |  95.0202%  |   99.3581s
# 3072 d  |  94.9798%  |   87.5013s
# 2048 d  |  94.8178%  |   57.4883s
# 1024 d  |  94.4939%  |   29.6964s
#  512 d  |  93.8057%  |   16.4421s
#  504 d  |  93.8866%  |   15.7597s
#  496 d  |  93.8057%  |   15.6233s
#  488 d  |  93.7652%  |   15.3404s
#  480 d  |  93.7247%  |   15.0536s
#  472 d  |  93.7652%  |   14.7977s
#  464 d  |  93.8057%  |   14.7158s
#  456 d  |  93.7652%  |   14.5692s
#  448 d  |  93.6842%  |   14.3969s
#  440 d  |  93.5628%  |   14.2381s
#  432 d  |  93.5223%  |   13.9428s
#  424 d  |  93.6032%  |   14.0046s
#  416 d  |  93.6032%  |   13.6727s
#  408 d  |  93.5628%  |   13.5728s
#  400 d  |  93.6032%  |   13.3905s
#  392 d  |  93.5223%  |   13.0533s
#  384 d  |  93.4008%  |   12.8413s
#  376 d  |  93.2794%  |   12.4153s
#  368 d  |  93.2794%  |   12.0985s
#  360 d  |  93.2389%  |   11.9688s
#  352 d  |  93.1579%  |   11.7205s
#  344 d  |  92.9555%  |   11.5171s
#  336 d  |  92.8745%  |   11.3801s
#  328 d  |  92.8745%  |   11.1568s
#  320 d  |  92.7126%  |   10.8814s
#  312 d  |  92.5911%  |   10.7416s
#  304 d  |  92.3887%  |   10.5377s
#  296 d  |  92.5506%  |   10.4184s
#  288 d  |  93.0769%  |   10.1855s
#  280 d  |  93.1579%  |    9.9632s
#  272 d  |  92.9555%  |    9.7931s
#  264 d  |  93.0364%  |    9.5435s
#  256 d  |  92.7935%  |    9.3839s
#  248 d  |  92.8745%  |    9.1377s
#  240 d  |  92.5911%  |    8.9192s
#  232 d  |  92.4291%  |    8.5756s
#  224 d  |  92.2267%  |    8.5350s
#  216 d  |  91.9838%  |    8.1986s
#  208 d  |  91.8623%  |    7.9734s
#  200 d  |  91.7409%  |    7.6921s
#  192 d  |  91.5789%  |    7.4458s
#  184 d  |  91.3765%  |    7.2308s
#  176 d  |  91.0526%  |    6.9511s
#  168 d  |  90.8502%  |    6.8448s
#  160 d  |  90.6073%  |    6.6011s
#  152 d  |  90.0810%  |    6.3164s
#  144 d  |  89.6356%  |    6.1132s
#  136 d  |  89.5547%  |    5.8922s
#  128 d  |  88.7854%  |    5.7095s
#  120 d  |  88.3806%  |    5.4877s
#  112 d  |  87.8543%  |    5.1778s
#  104 d  |  86.5587%  |    5.0233s
#   96 d  |  84.9798%  |    4.8325s
#   88 d  |  83.1579%  |    4.5491s
#   80 d  |  80.5263%  |    4.3103s
#   72 d  |  76.8826%  |    4.1680s
#   64 d  |  78.4211%  |    3.8344s
#   56 d  |  71.7814%  |    3.6586s
#   48 d  |  62.7126%  |    3.4405s
#   40 d  |  50.6478%  |    3.2009s
#   32 d  |  39.5547%  |    3.0131s
#   16 d  |   6.5587%  |    2.6951s

# %%
save_json(knn_results, "truncate_first_knn_medians.json")
# Out:
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/truncate_first_knn_medians.json

# %%
print(knn_results)
# Out:
# {3584: {'accuracy_pct': 95.0202, 'median_time_s': 99.3581}, 3072: {'accuracy_pct': 94.9798, 'median_time_s': 87.5013}, 2048: {'accuracy_pct': 94.8178, 'median_time_s': 57.4883}, 1024: {'accuracy_pct': 94.4939, 'median_time_s': 29.6964}, 512: {'accuracy_pct': 93.8057, 'median_time_s': 16.4421}, 504: {'accuracy_pct': 93.8866, 'median_time_s': 15.7597}, 496: {'accuracy_pct': 93.8057, 'median_time_s': 15.6233}, 488: {'accuracy_pct': 93.7652, 'median_time_s': 15.3404}, 480: {'accuracy_pct': 93.7247, 'median_time_s': 15.0536}, 472: {'accuracy_pct': 93.7652, 'median_time_s': 14.7977}, 464: {'accuracy_pct': 93.8057, 'median_time_s': 14.7158}, 456: {'accuracy_pct': 93.7652, 'median_time_s': 14.5692}, 448: {'accuracy_pct': 93.6842, 'median_time_s': 14.3969}, 440: {'accuracy_pct': 93.5628, 'median_time_s': 14.2381}, 432: {'accuracy_pct': 93.5223, 'median_time_s': 13.9428}, 424: {'accuracy_pct': 93.6032, 'median_time_s': 14.0046}, 416: {'accuracy_pct': 93.6032, 'median_time_s': 13.6727}, 408: {'accuracy_pct': 93.5628, 'median_time_s': 13.5728}, 400: {'accuracy_pct': 93.6032, 'median_time_s': 13.3905}, 392: {'accuracy_pct': 93.5223, 'median_time_s': 13.0533}, 384: {'accuracy_pct': 93.4008, 'median_time_s': 12.8413}, 376: {'accuracy_pct': 93.2794, 'median_time_s': 12.4153}, 368: {'accuracy_pct': 93.2794, 'median_time_s': 12.0985}, 360: {'accuracy_pct': 93.2389, 'median_time_s': 11.9688}, 352: {'accuracy_pct': 93.1579, 'median_time_s': 11.7205}, 344: {'accuracy_pct': 92.9555, 'median_time_s': 11.5171}, 336: {'accuracy_pct': 92.8745, 'median_time_s': 11.3801}, 328: {'accuracy_pct': 92.8745, 'median_time_s': 11.1568}, 320: {'accuracy_pct': 92.7126, 'median_time_s': 10.8814}, 312: {'accuracy_pct': 92.5911, 'median_time_s': 10.7416}, 304: {'accuracy_pct': 92.3887, 'median_time_s': 10.5377}, 296: {'accuracy_pct': 92.5506, 'median_time_s': 10.4184}, 288: {'accuracy_pct': 93.0769, 'median_time_s': 10.1855}, 280: {'accuracy_pct': 93.1579, 'median_time_s': 9.9632}, 272: {'accuracy_pct': 92.9555, 'median_time_s': 9.7931}, 264: {'accuracy_pct': 93.0364, 'median_time_s': 9.5435}, 256: {'accuracy_pct': 92.7935, 'median_time_s': 9.3839}, 248: {'accuracy_pct': 92.8745, 'median_time_s': 9.1377}, 240: {'accuracy_pct': 92.5911, 'median_time_s': 8.9192}, 232: {'accuracy_pct': 92.4291, 'median_time_s': 8.5756}, 224: {'accuracy_pct': 92.2267, 'median_time_s': 8.535}, 216: {'accuracy_pct': 91.9838, 'median_time_s': 8.1986}, 208: {'accuracy_pct': 91.8623, 'median_time_s': 7.9734}, 200: {'accuracy_pct': 91.7409, 'median_time_s': 7.6921}, 192: {'accuracy_pct': 91.5789, 'median_time_s': 7.4458}, 184: {'accuracy_pct': 91.3765, 'median_time_s': 7.2308}, 176: {'accuracy_pct': 91.0526, 'median_time_s': 6.9511}, 168: {'accuracy_pct': 90.8502, 'median_time_s': 6.8448}, 160: {'accuracy_pct': 90.6073, 'median_time_s': 6.6011}, 152: {'accuracy_pct': 90.081, 'median_time_s': 6.3164}, 144: {'accuracy_pct': 89.6356, 'median_time_s': 6.1132}, 136: {'accuracy_pct': 89.5547, 'median_time_s': 5.8922}, 128: {'accuracy_pct': 88.7854, 'median_time_s': 5.7095}, 120: {'accuracy_pct': 88.3806, 'median_time_s': 5.4877}, 112: {'accuracy_pct': 87.8543, 'median_time_s': 5.1778}, 104: {'accuracy_pct': 86.5587, 'median_time_s': 5.0233}, 96: {'accuracy_pct': 84.9798, 'median_time_s': 4.8325}, 88: {'accuracy_pct': 83.1579, 'median_time_s': 4.5491}, 80: {'accuracy_pct': 80.5263, 'median_time_s': 4.3103}, 72: {'accuracy_pct': 76.8826, 'median_time_s': 4.168}, 64: {'accuracy_pct': 78.4211, 'median_time_s': 3.8344}, 56: {'accuracy_pct': 71.7814, 'median_time_s': 3.6586}, 48: {'accuracy_pct': 62.7126, 'median_time_s': 3.4405}, 40: {'accuracy_pct': 50.6478, 'median_time_s': 3.2009}, 32: {'accuracy_pct': 39.5547, 'median_time_s': 3.0131}, 16: {'accuracy_pct': 6.5587, 'median_time_s': 2.6951}}

# %% [markdown]
# ### Progressive Truncation KNN

# %%
prog_stats = {}
dim_grid   = [64, 128, 256, 512, 1024, 2048, 3584]
start_k_ls = [2**i for i in range(2, 11)]
JSON_NAME  = "progressive_knn_medians.json"
JSON_PATH  = f"{drive_root}/{JSON_NAME}"

# %% [markdown]
# #### Initial Run

# %%
prog_stats = {}
dim_grid   = [64, 128, 256, 512, 1024, 2048, 3584]
start_k_ls = [2**i for i in range(2, 11)]

for startD in dim_grid:
    for maxD in dim_grid:
        if startD >= maxD:
            continue        # strictly ascending range

        for k0 in start_k_ls:
            key = (startD, maxD, k0)
            times, accs = [], []

            for run in range(10):
                res = progressive_knn_sklearn(
                    ds_embs     = dataset_embs,
                    qs_embs     = question_embs,
                    df_dataset  = df_dataset,
                    contexts    = contexts,
                    start_dim   = startD,
                    start_k     = k0,
                    max_dim     = maxD,
                    step_factor = 2,
                    step_k      = 2,
                    step_add    = None,
                    verbose     = False    # suppress per‑slice chatter
                )
                times.append(res["t_total_s"])
                accs.append(res["accuracy_pct"])
                gc.collect()

            # ---------- summarise one scenario -----------------
            times_sorted  = sorted(times)
            median_time   = round(float(np.median(times_sorted)), 4)
            acc_unique    = set(accs)
            # acc_final     = round(accs[0], 4) if len(acc_unique)==1 else sorted(acc_unique)[-1]
            if len(acc_unique) != 1:
                print(f"accuracy drift at [{startD:4d}->{maxD:<4d} | k={k0:4d}]")
            acc_final = round(accs[0], 4)

            print(f"[{startD:4d}->{maxD:<4d} | k={k0:4d}] "
                  f"times={times_sorted}  →  median={median_time:.4f}s  "
                  f"| acc={acc_final:.4f}%")

            prog_stats[key] = {
                "accuracy_pct" : acc_final,
                "median_time_s": median_time,
                # "times_s"      : [round(t, 4) for t in times_sorted]
            }

# ---------------- summary ------------------
print("\n=== MEDIAN TIMES (s) ===")
for (sD,mD,k0), stats in sorted(prog_stats.items()):
    print(f"{sD:4}->{mD:<4}  k={k0:4} | "
          f"{stats['accuracy_pct']:7.4f}%  | {stats['median_time_s']:8.4f}s")

# --------------- save to JSON for later plotting -----------------
save_json(prog_stats, "progressive_knn_medians.json")
print("\nSaved → progressive_knn_medians.json")
# Out:
# [  64->128  | k=   4] times=[3.93, 3.93, 3.95, 3.97, 4.02, 4.06, 4.07, 4.07, 4.17, 4.17]  →  median=4.0400s  | acc=83.7247%
# [  64->128  | k=   8] times=[3.99, 3.99, 4.0, 4.04, 4.06, 4.08, 4.08, 4.18, 4.27, 4.27]  →  median=4.0700s  | acc=85.2227%
# [  64->128  | k=  16] times=[4.22, 4.25, 4.25, 4.27, 4.28, 4.3, 4.36, 4.38, 4.45, 4.52]  →  median=4.2900s  | acc=86.4372%
# [  64->128  | k=  32] times=[4.58, 4.58, 4.68, 4.71, 4.72, 4.78, 4.79, 4.79, 4.88, 4.91]  →  median=4.7500s  | acc=87.2470%
# [  64->128  | k=  64] times=[5.36, 5.39, 5.39, 5.4, 5.43, 5.52, 5.54, 5.55, 5.56, 5.6]  →  median=5.4750s  | acc=87.8947%
# [  64->128  | k= 128] times=[6.34, 6.35, 6.4, 6.43, 6.49, 6.53, 6.54, 6.59, 6.62, 6.62]  →  median=6.5100s  | acc=88.5020%
# [  64->128  | k= 256] times=[7.63, 7.78, 8.0, 8.08, 8.09, 8.12, 8.14, 8.17, 8.2, 8.22]  →  median=8.1050s  | acc=88.5830%
# [  64->128  | k= 512] times=[9.14, 9.27, 9.28, 9.32, 9.33, 9.36, 9.37, 9.39, 9.45, 9.47]  →  median=9.3450s  | acc=88.7449%
# [  64->128  | k=1024] times=[12.86, 12.91, 12.95, 12.95, 12.99, 13.0, 13.0, 13.01, 13.05, 13.09]  →  median=12.9950s  | acc=88.7449%
# [  64->256  | k=   4] times=[3.95, 3.95, 3.96, 3.99, 4.02, 4.06, 4.07, 4.15, 4.17, 4.21]  →  median=4.0400s  | acc=84.8178%
# [  64->256  | k=   8] times=[4.1, 4.12, 4.14, 4.15, 4.23, 4.23, 4.31, 4.33, 4.33, 4.42]  →  median=4.2300s  | acc=86.6397%
# [  64->256  | k=  16] times=[4.42, 4.44, 4.46, 4.46, 4.5, 4.52, 4.6, 4.68, 4.73, 4.75]  →  median=4.5100s  | acc=88.4211%
# [  64->256  | k=  32] times=[5.0, 5.03, 5.05, 5.08, 5.1, 5.18, 5.24, 5.28, 5.3, 5.33]  →  median=5.1400s  | acc=89.7571%
# [  64->256  | k=  64] times=[6.06, 6.07, 6.07, 6.13, 6.14, 6.24, 6.29, 6.34, 6.36, 6.45]  →  median=6.1900s  | acc=90.5263%
# [  64->256  | k= 128] times=[7.74, 7.77, 7.8, 7.81, 7.83, 7.83, 7.85, 7.87, 7.88, 7.9]  →  median=7.8300s  | acc=91.5385%
# [  64->256  | k= 256] times=[10.59, 10.59, 10.61, 10.62, 10.65, 10.66, 10.68, 10.68, 10.79, 10.81]  →  median=10.6550s  | acc=91.9838%
# [  64->256  | k= 512] times=[14.39, 14.47, 14.55, 14.59, 14.59, 14.6, 14.68, 14.84, 14.84, 14.84]  →  median=14.5950s  | acc=92.4696%
# [  64->256  | k=1024] times=[19.84, 19.84, 19.88, 19.89, 19.94, 19.94, 19.96, 19.97, 19.97, 20.04]  →  median=19.9400s  | acc=92.6721%
# [  64->512  | k=   4] times=[3.98, 4.01, 4.01, 4.02, 4.1, 4.12, 4.18, 4.18, 4.22, 4.28]  →  median=4.1100s  | acc=84.8178%
# [  64->512  | k=   8] times=[4.21, 4.22, 4.25, 4.28, 4.3, 4.32, 4.32, 4.39, 4.5, 4.55]  →  median=4.3100s  | acc=86.8016%
# [  64->512  | k=  16] times=[4.63, 4.64, 4.67, 4.67, 4.67, 4.77, 4.77, 4.92, 4.92, 4.93]  →  median=4.7200s  | acc=88.7854%
# [  64->512  | k=  32] times=[5.39, 5.44, 5.46, 5.52, 5.54, 5.67, 5.72, 5.72, 5.72, 5.79]  →  median=5.6050s  | acc=90.1215%
# [  64->512  | k=  64] times=[6.8, 6.88, 7.01, 7.03, 7.04, 7.06, 7.07, 7.1, 7.13, 7.22]  →  median=7.0500s  | acc=91.0526%
# [  64->512  | k= 128] times=[9.17, 9.28, 9.31, 9.32, 9.35, 9.37, 9.44, 9.49, 9.5, 9.59]  →  median=9.3600s  | acc=92.1457%
# [  64->512  | k= 256] times=[13.1, 13.11, 13.12, 13.19, 13.19, 13.23, 13.26, 13.27, 13.29, 13.36]  →  median=13.2100s  | acc=92.7126%
# [  64->512  | k= 512] times=[18.72, 18.79, 18.97, 19.02, 19.03, 19.05, 19.11, 19.11, 19.12, 19.15]  →  median=19.0400s  | acc=93.3198%
# [  64->512  | k=1024] times=[26.87, 27.0, 27.09, 27.16, 27.2, 27.22, 27.22, 27.26, 27.35, 27.36]  →  median=27.2100s  | acc=93.5628%
# [  64->1024 | k=   4] times=[4.32, 4.34, 4.34, 4.36, 4.38, 4.4, 4.43, 4.49, 4.5, 4.53]  →  median=4.3900s  | acc=84.8178%
# [  64->1024 | k=   8] times=[4.52, 4.53, 4.55, 4.56, 4.59, 4.6, 4.62, 4.64, 4.64, 4.71]  →  median=4.5950s  | acc=86.8016%
# [  64->1024 | k=  16] times=[4.94, 5.02, 5.02, 5.05, 5.06, 5.11, 5.11, 5.12, 5.12, 5.22]  →  median=5.0850s  | acc=89.1498%
# [  64->1024 | k=  32] times=[5.91, 5.95, 5.97, 5.98, 6.01, 6.02, 6.04, 6.07, 6.08, 6.1]  →  median=6.0150s  | acc=90.5263%
# [  64->1024 | k=  64] times=[7.71, 7.72, 7.78, 7.79, 7.81, 7.83, 7.83, 7.83, 7.83, 7.84]  →  median=7.8200s  | acc=91.4980%
# [  64->1024 | k= 128] times=[10.26, 10.29, 10.35, 10.47, 10.49, 10.5, 10.51, 10.51, 10.54, 10.82]  →  median=10.4950s  | acc=92.6316%
# [  64->1024 | k= 256] times=[13.67, 13.71, 13.81, 13.82, 13.82, 14.01, 14.09, 14.1, 14.18, 14.99]  →  median=13.9150s  | acc=93.2794%
# [  64->1024 | k= 512] times=[20.37, 20.6, 20.62, 20.65, 20.73, 20.79, 20.8, 20.81, 20.83, 20.86]  →  median=20.7600s  | acc=93.9271%
# [  64->1024 | k=1024] times=[31.49, 32.74, 33.44, 33.58, 33.65, 33.8, 33.81, 34.01, 34.16, 34.82]  →  median=33.7250s  | acc=94.2105%
# [  64->2048 | k=   4] times=[4.31, 4.34, 4.36, 4.36, 4.37, 4.42, 4.44, 4.51, 4.56, 4.59]  →  median=4.3950s  | acc=84.8178%
# [  64->2048 | k=   8] times=[4.51, 4.52, 4.55, 4.59, 4.62, 4.65, 4.77, 4.79, 4.88, 4.91]  →  median=4.6350s  | acc=86.8016%
# [  64->2048 | k=  16] times=[4.86, 4.9, 4.91, 4.92, 4.93, 4.94, 4.98, 5.03, 5.1, 5.1]  →  median=4.9350s  | acc=89.1498%
# [  64->2048 | k=  32] times=[5.74, 5.77, 5.84, 5.91, 5.95, 6.0, 6.01, 6.02, 6.05, 6.12]  →  median=5.9750s  | acc=90.7287%
# [  64->2048 | k=  64] times=[7.56, 7.56, 7.59, 7.6, 7.68, 7.7, 7.74, 7.74, 7.76, 7.76]  →  median=7.6900s  | acc=91.7409%
# [  64->2048 | k= 128] times=[10.64, 10.65, 10.72, 10.72, 10.72, 10.75, 10.76, 10.78, 10.85, 11.64]  →  median=10.7350s  | acc=92.7935%
# [  64->2048 | k= 256] times=[17.14, 17.18, 17.19, 17.2, 17.34, 17.38, 17.51, 17.56, 17.61, 17.69]  →  median=17.3600s  | acc=93.5223%

# %% [markdown]
# #### Continue Run 1

# %%
if os.path.exists(JSON_PATH):
    with open(JSON_PATH) as f:
        prog_stats = {tuple(map(int, k.strip("()").split(","))): v
                      for k, v in json.load(f).items()}
    print(f"↩️  loaded {len(prog_stats)} scenarios from {JSON_NAME}")
# Out:
# ↩️  loaded 43 scenarios from progressive_knn_medians.json

# %%
LOG_TEXT = """
[  64->128  | k=   4] times=[3.93, 3.93, 3.95, 3.97, 4.02, 4.06, 4.07, 4.07, 4.17, 4.17]  →  median=4.0400s  | acc=83.7247%
[  64->128  | k=   8] times=[3.99, 3.99, 4.0, 4.04, 4.06, 4.08, 4.08, 4.18, 4.27, 4.27]  →  median=4.0700s  | acc=85.2227%
[  64->128  | k=  16] times=[4.22, 4.25, 4.25, 4.27, 4.28, 4.3, 4.36, 4.38, 4.45, 4.52]  →  median=4.2900s  | acc=86.4372%
[  64->128  | k=  32] times=[4.58, 4.58, 4.68, 4.71, 4.72, 4.78, 4.79, 4.79, 4.88, 4.91]  →  median=4.7500s  | acc=87.2470%
[  64->128  | k=  64] times=[5.36, 5.39, 5.39, 5.4, 5.43, 5.52, 5.54, 5.55, 5.56, 5.6]  →  median=5.4750s  | acc=87.8947%
[  64->128  | k= 128] times=[6.34, 6.35, 6.4, 6.43, 6.49, 6.53, 6.54, 6.59, 6.62, 6.62]  →  median=6.5100s  | acc=88.5020%
[  64->128  | k= 256] times=[7.63, 7.78, 8.0, 8.08, 8.09, 8.12, 8.14, 8.17, 8.2, 8.22]  →  median=8.1050s  | acc=88.5830%
[  64->128  | k= 512] times=[9.14, 9.27, 9.28, 9.32, 9.33, 9.36, 9.37, 9.39, 9.45, 9.47]  →  median=9.3450s  | acc=88.7449%
[  64->128  | k=1024] times=[12.86, 12.91, 12.95, 12.95, 12.99, 13.0, 13.0, 13.01, 13.05, 13.09]  →  median=12.9950s  | acc=88.7449%
[  64->256  | k=   4] times=[3.95, 3.95, 3.96, 3.99, 4.02, 4.06, 4.07, 4.15, 4.17, 4.21]  →  median=4.0400s  | acc=84.8178%
[  64->256  | k=   8] times=[4.1, 4.12, 4.14, 4.15, 4.23, 4.23, 4.31, 4.33, 4.33, 4.42]  →  median=4.2300s  | acc=86.6397%
[  64->256  | k=  16] times=[4.42, 4.44, 4.46, 4.46, 4.5, 4.52, 4.6, 4.68, 4.73, 4.75]  →  median=4.5100s  | acc=88.4211%
[  64->256  | k=  32] times=[5.0, 5.03, 5.05, 5.08, 5.1, 5.18, 5.24, 5.28, 5.3, 5.33]  →  median=5.1400s  | acc=89.7571%
[  64->256  | k=  64] times=[6.06, 6.07, 6.07, 6.13, 6.14, 6.24, 6.29, 6.34, 6.36, 6.45]  →  median=6.1900s  | acc=90.5263%
[  64->256  | k= 128] times=[7.74, 7.77, 7.8, 7.81, 7.83, 7.83, 7.85, 7.87, 7.88, 7.9]  →  median=7.8300s  | acc=91.5385%
[  64->256  | k= 256] times=[10.59, 10.59, 10.61, 10.62, 10.65, 10.66, 10.68, 10.68, 10.79, 10.81]  →  median=10.6550s  | acc=91.9838%
[  64->256  | k= 512] times=[14.39, 14.47, 14.55, 14.59, 14.59, 14.6, 14.68, 14.84, 14.84, 14.84]  →  median=14.5950s  | acc=92.4696%
[  64->256  | k=1024] times=[19.84, 19.84, 19.88, 19.89, 19.94, 19.94, 19.96, 19.97, 19.97, 20.04]  →  median=19.9400s  | acc=92.6721%
[  64->512  | k=   4] times=[3.98, 4.01, 4.01, 4.02, 4.1, 4.12, 4.18, 4.18, 4.22, 4.28]  →  median=4.1100s  | acc=84.8178%
[  64->512  | k=   8] times=[4.21, 4.22, 4.25, 4.28, 4.3, 4.32, 4.32, 4.39, 4.5, 4.55]  →  median=4.3100s  | acc=86.8016%
[  64->512  | k=  16] times=[4.63, 4.64, 4.67, 4.67, 4.67, 4.77, 4.77, 4.92, 4.92, 4.93]  →  median=4.7200s  | acc=88.7854%
[  64->512  | k=  32] times=[5.39, 5.44, 5.46, 5.52, 5.54, 5.67, 5.72, 5.72, 5.72, 5.79]  →  median=5.6050s  | acc=90.1215%
[  64->512  | k=  64] times=[6.8, 6.88, 7.01, 7.03, 7.04, 7.06, 7.07, 7.1, 7.13, 7.22]  →  median=7.0500s  | acc=91.0526%
[  64->512  | k= 128] times=[9.17, 9.28, 9.31, 9.32, 9.35, 9.37, 9.44, 9.49, 9.5, 9.59]  →  median=9.3600s  | acc=92.1457%
[  64->512  | k= 256] times=[13.1, 13.11, 13.12, 13.19, 13.19, 13.23, 13.26, 13.27, 13.29, 13.36]  →  median=13.2100s  | acc=92.7126%
[  64->512  | k= 512] times=[18.72, 18.79, 18.97, 19.02, 19.03, 19.05, 19.11, 19.11, 19.12, 19.15]  →  median=19.0400s  | acc=93.3198%
[  64->512  | k=1024] times=[26.87, 27.0, 27.09, 27.16, 27.2, 27.22, 27.22, 27.26, 27.35, 27.36]  →  median=27.2100s  | acc=93.5628%
[  64->1024 | k=   4] times=[4.32, 4.34, 4.34, 4.36, 4.38, 4.4, 4.43, 4.49, 4.5, 4.53]  →  median=4.3900s  | acc=84.8178%
[  64->1024 | k=   8] times=[4.52, 4.53, 4.55, 4.56, 4.59, 4.6, 4.62, 4.64, 4.64, 4.71]  →  median=4.5950s  | acc=86.8016%
[  64->1024 | k=  16] times=[4.94, 5.02, 5.02, 5.05, 5.06, 5.11, 5.11, 5.12, 5.12, 5.22]  →  median=5.0850s  | acc=89.1498%
[  64->1024 | k=  32] times=[5.91, 5.95, 5.97, 5.98, 6.01, 6.02, 6.04, 6.07, 6.08, 6.1]  →  median=6.0150s  | acc=90.5263%
[  64->1024 | k=  64] times=[7.71, 7.72, 7.78, 7.79, 7.81, 7.83, 7.83, 7.83, 7.83, 7.84]  →  median=7.8200s  | acc=91.4980%
[  64->1024 | k= 128] times=[10.26, 10.29, 10.35, 10.47, 10.49, 10.5, 10.51, 10.51, 10.54, 10.82]  →  median=10.4950s  | acc=92.6316%
[  64->1024 | k= 256] times=[13.67, 13.71, 13.81, 13.82, 13.82, 14.01, 14.09, 14.1, 14.18, 14.99]  →  median=13.9150s  | acc=93.2794%
[  64->1024 | k= 512] times=[20.37, 20.6, 20.62, 20.65, 20.73, 20.79, 20.8, 20.81, 20.83, 20.86]  →  median=20.7600s  | acc=93.9271%
[  64->1024 | k=1024] times=[31.49, 32.74, 33.44, 33.58, 33.65, 33.8, 33.81, 34.01, 34.16, 34.82]  →  median=33.7250s  | acc=94.2105%
[  64->2048 | k=   4] times=[4.31, 4.34, 4.36, 4.36, 4.37, 4.42, 4.44, 4.51, 4.56, 4.59]  →  median=4.3950s  | acc=84.8178%
[  64->2048 | k=   8] times=[4.51, 4.52, 4.55, 4.59, 4.62, 4.65, 4.77, 4.79, 4.88, 4.91]  →  median=4.6350s  | acc=86.8016%
[  64->2048 | k=  16] times=[4.86, 4.9, 4.91, 4.92, 4.93, 4.94, 4.98, 5.03, 5.1, 5.1]  →  median=4.9350s  | acc=89.1498%
[  64->2048 | k=  32] times=[5.74, 5.77, 5.84, 5.91, 5.95, 6.0, 6.01, 6.02, 6.05, 6.12]  →  median=5.9750s  | acc=90.7287%
[  64->2048 | k=  64] times=[7.56, 7.56, 7.59, 7.6, 7.68, 7.7, 7.74, 7.74, 7.76, 7.76]  →  median=7.6900s  | acc=91.7409%
[  64->2048 | k= 128] times=[10.64, 10.65, 10.72, 10.72, 10.72, 10.75, 10.76, 10.78, 10.85, 11.64]  →  median=10.7350s  | acc=92.7935%
[  64->2048 | k= 256] times=[17.14, 17.18, 17.19, 17.2, 17.34, 17.38, 17.51, 17.56, 17.61, 17.69]  →  median=17.3600s  | acc=93.5223%
"""

# %%
if LOG_TEXT.strip():
    pat = re.compile(
        r"\[\s*(\d+)->(\d+)\s*\|\s*k=\s*(\d+)\]\s*times=\[([0-9\.,\s]+)\]"
        r".*?median=([\d\.]+)s.*?acc=([\d\.]+)%"
    )
    added = 0
    for sD, mD, k0, t_list, med, acc in pat.findall(LOG_TEXT):
        key = (int(sD), int(mD), int(k0))
        if key not in prog_stats:
            times_sorted = sorted(round(float(x), 4)
                                  for x in t_list.split(","))
            prog_stats[key] = {
                "accuracy_pct" : round(float(acc), 4),
                "median_time_s": round(float(med), 4),
                # "times_s"      : times_sorted
            }
            added += 1
    # if added:
    #     save_json(prog_stats, JSON_PATH)          # persist immediately
    #     print(f"imported {added} scenarios from LOG_TEXT")

# %%
print(prog_stats)
# Out:
# {(64, 128, 4): {'accuracy_pct': 83.7247, 'median_time_s': 4.04}, (64, 128, 8): {'accuracy_pct': 85.2227, 'median_time_s': 4.07}, (64, 128, 16): {'accuracy_pct': 86.4372, 'median_time_s': 4.29}, (64, 128, 32): {'accuracy_pct': 87.247, 'median_time_s': 4.75}, (64, 128, 64): {'accuracy_pct': 87.8947, 'median_time_s': 5.475}, (64, 128, 128): {'accuracy_pct': 88.502, 'median_time_s': 6.51}, (64, 128, 256): {'accuracy_pct': 88.583, 'median_time_s': 8.105}, (64, 128, 512): {'accuracy_pct': 88.7449, 'median_time_s': 9.345}, (64, 128, 1024): {'accuracy_pct': 88.7449, 'median_time_s': 12.995}, (64, 256, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.04}, (64, 256, 8): {'accuracy_pct': 86.6397, 'median_time_s': 4.23}, (64, 256, 16): {'accuracy_pct': 88.4211, 'median_time_s': 4.51}, (64, 256, 32): {'accuracy_pct': 89.7571, 'median_time_s': 5.14}, (64, 256, 64): {'accuracy_pct': 90.5263, 'median_time_s': 6.19}, (64, 256, 128): {'accuracy_pct': 91.5385, 'median_time_s': 7.83}, (64, 256, 256): {'accuracy_pct': 91.9838, 'median_time_s': 10.655}, (64, 256, 512): {'accuracy_pct': 92.4696, 'median_time_s': 14.595}, (64, 256, 1024): {'accuracy_pct': 92.6721, 'median_time_s': 19.94}, (64, 512, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.11}, (64, 512, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.31}, (64, 512, 16): {'accuracy_pct': 88.7854, 'median_time_s': 4.72}, (64, 512, 32): {'accuracy_pct': 90.1215, 'median_time_s': 5.605}, (64, 512, 64): {'accuracy_pct': 91.0526, 'median_time_s': 7.05}, (64, 512, 128): {'accuracy_pct': 92.1457, 'median_time_s': 9.36}, (64, 512, 256): {'accuracy_pct': 92.7126, 'median_time_s': 13.21}, (64, 512, 512): {'accuracy_pct': 93.3198, 'median_time_s': 19.04}, (64, 512, 1024): {'accuracy_pct': 93.5628, 'median_time_s': 27.21}, (64, 1024, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.39}, (64, 1024, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.595}, (64, 1024, 16): {'accuracy_pct': 89.1498, 'median_time_s': 5.085}, (64, 1024, 32): {'accuracy_pct': 90.5263, 'median_time_s': 6.015}, (64, 1024, 64): {'accuracy_pct': 91.498, 'median_time_s': 7.82}, (64, 1024, 128): {'accuracy_pct': 92.6316, 'median_time_s': 10.495}, (64, 1024, 256): {'accuracy_pct': 93.2794, 'median_time_s': 13.915}, (64, 1024, 512): {'accuracy_pct': 93.9271, 'median_time_s': 20.76}, (64, 1024, 1024): {'accuracy_pct': 94.2105, 'median_time_s': 33.725}, (64, 2048, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.395}, (64, 2048, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.635}, (64, 2048, 16): {'accuracy_pct': 89.1498, 'median_time_s': 4.935}, (64, 2048, 32): {'accuracy_pct': 90.7287, 'median_time_s': 5.975}, (64, 2048, 64): {'accuracy_pct': 91.7409, 'median_time_s': 7.69}, (64, 2048, 128): {'accuracy_pct': 92.7935, 'median_time_s': 10.735}, (64, 2048, 256): {'accuracy_pct': 93.5223, 'median_time_s': 17.36}}

# %%
save_json(prog_stats, JSON_NAME)
# Out:
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json

# %%
for startD in dim_grid:
    for maxD in dim_grid:
        if startD >= maxD:         # strictly ascending
            continue
        for k0 in start_k_ls:
            key = (startD, maxD, k0)
            if key in prog_stats:  # already done or ingested
                continue

            times, accs = [], []
            for _ in range(10):
                res = progressive_knn_sklearn(
                    ds_embs     = dataset_embs,
                    qs_embs     = question_embs,
                    df_dataset  = df_dataset,
                    contexts    = contexts,
                    start_dim   = startD,
                    start_k     = k0,
                    max_dim     = maxD,
                    step_factor = 2,
                    step_k      = 2,
                    step_add    = None,
                    verbose     = False
                )
                times.append(res["t_total_s"])
                accs.append(res["accuracy_pct"])
                gc.collect()

            times_sorted = sorted(round(t, 4) for t in times)
            median_time  = round(float(np.median(times_sorted)), 4)
            acc_unique   = set(accs)
            if len(acc_unique) != 1:
                print(f"accuracy drift at [{startD:4d}->{maxD:<4d} | k={k0:4d}]")
            acc_final = round(accs[0], 4)

            # ---- identical print format to your original ---------
            print(f"[{startD:4d}->{maxD:<4d} | k={k0:4d}] "
                  f"times={times_sorted}  →  median={median_time:.4f}s  "
                  f"| acc={acc_final:.4f}%")

            prog_stats[key] = {
                "accuracy_pct" : acc_final,
                "median_time_s": median_time,
                # "times_s"      : times_sorted
            }
            save_json(prog_stats, JSON_NAME)   # overwrite after each scenario

# ==============================================================
print("\n=== MEDIAN TIMES (s) ===")
for (sD, mD, k0), st in sorted(prog_stats.items()):
    print(f"{sD:4}->{mD:<4}  k={k0:4} | "
          f"{st['accuracy_pct']:7.4f}%  | {st['median_time_s']:8.4f}s")
# Out:
# [  64->2048 | k= 512] times=[24.89, 25.0, 25.05, 25.09, 25.15, 25.18, 25.35, 25.44, 25.56, 26.03]  →  median=25.1650s  | acc=94.2105%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [  64->2048 | k=1024] times=[41.24, 41.36, 41.98, 41.99, 42.07, 42.2, 42.21, 42.58, 44.1, 47.19]  →  median=42.1350s  | acc=94.6154%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [  64->3584 | k=   4] times=[4.56, 4.62, 4.64, 4.65, 4.65, 4.67, 4.67, 4.68, 4.78, 4.84]  →  median=4.6600s  | acc=84.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [  64->3584 | k=   8] times=[4.86, 4.89, 4.89, 4.91, 4.91, 4.93, 4.98, 4.99, 5.02, 5.05]  →  median=4.9200s  | acc=86.8016%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [  64->3584 | k=  16] times=[5.34, 5.37, 5.39, 5.41, 5.41, 5.41, 5.53, 5.56, 5.61, 5.65]  →  median=5.4100s  | acc=89.1498%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [  64->3584 | k=  32] times=[6.33, 6.34, 6.42, 6.42, 6.46, 6.52, 6.52, 6.53, 6.53, 6.65]  →  median=6.4900s  | acc=90.7287%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [  64->3584 | k=  64] times=[8.57, 8.61, 8.62, 8.63, 8.68, 8.7, 8.79, 8.8, 8.84, 8.84]  →  median=8.6900s  | acc=91.7409%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [  64->3584 | k= 128] times=[12.5, 12.6, 12.6, 12.64, 12.67, 12.68, 12.69, 12.78, 12.82, 12.83]  →  median=12.6750s  | acc=92.8340%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [  64->3584 | k= 256] times=[18.16, 18.2, 18.34, 18.41, 18.42, 19.63, 19.71, 19.71, 19.81, 19.95]  →  median=19.0250s  | acc=93.6032%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [  64->3584 | k= 512] times=[28.59, 28.67, 28.73, 31.03, 31.1, 31.24, 31.27, 31.28, 31.35, 31.85]  →  median=31.1700s  | acc=94.3320%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [  64->3584 | k=1024] times=[49.41, 49.49, 49.62, 49.66, 49.69, 49.83, 49.83, 49.99, 50.04, 50.23]  →  median=49.7600s  | acc=94.7368%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->256  | k=   4] times=[5.71, 5.74, 5.75, 5.76, 5.78, 5.85, 5.89, 5.92, 5.94, 5.98]  →  median=5.8150s  | acc=92.2267%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->256  | k=   8] times=[5.84, 5.86, 5.86, 5.87, 5.93, 5.93, 5.94, 5.99, 6.03, 6.04]  →  median=5.9300s  | acc=92.3077%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->256  | k=  16] times=[6.11, 6.15, 6.17, 6.2, 6.22, 6.23, 6.24, 6.25, 6.26, 6.28]  →  median=6.2250s  | acc=92.5506%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->256  | k=  32] times=[6.43, 6.49, 6.53, 6.53, 6.55, 6.55, 6.59, 6.6, 6.65, 6.72]  →  median=6.5500s  | acc=92.5911%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->256  | k=  64] times=[7.37, 7.38, 7.41, 7.44, 7.48, 7.57, 7.6, 7.6, 7.61, 7.62]  →  median=7.5250s  | acc=92.6721%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->256  | k= 128] times=[8.67, 8.76, 8.79, 8.83, 8.93, 8.94, 8.95, 8.95, 9.0, 9.02]  →  median=8.9350s  | acc=92.7935%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->256  | k= 256] times=[10.71, 10.73, 10.76, 10.8, 10.81, 10.84, 10.85, 10.91, 10.95, 10.96]  →  median=10.8250s  | acc=92.7935%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->256  | k= 512] times=[13.2, 13.27, 13.32, 13.37, 13.4, 13.41, 13.45, 13.45, 13.52, 13.64]  →  median=13.4050s  | acc=92.7935%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->256  | k=1024] times=[16.28, 16.5, 16.56, 16.56, 16.57, 16.58, 16.58, 16.63, 16.66, 16.79]  →  median=16.5750s  | acc=92.7935%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->512  | k=   4] times=[6.03, 6.03, 6.04, 6.06, 6.06, 6.06, 6.08, 6.09, 6.11, 6.13]  →  median=6.0600s  | acc=92.3077%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->512  | k=   8] times=[5.92, 6.09, 6.22, 6.24, 6.25, 6.27, 6.3, 6.31, 6.34, 6.36]  →  median=6.2600s  | acc=92.7126%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->512  | k=  16] times=[6.57, 6.6, 6.6, 6.64, 6.72, 6.73, 6.74, 6.76, 6.78, 6.82]  →  median=6.7250s  | acc=93.1174%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->512  | k=  32] times=[7.31, 7.32, 7.46, 7.51, 7.53, 7.57, 7.57, 7.58, 7.59, 7.62]  →  median=7.5500s  | acc=93.4008%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->512  | k=  64] times=[8.81, 8.85, 8.91, 9.01, 9.08, 9.1, 9.1, 9.11, 9.11, 9.13]  →  median=9.0900s  | acc=93.4818%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->512  | k= 128] times=[11.43, 11.57, 11.57, 11.59, 11.61, 11.62, 11.64, 11.69, 11.75, 11.83]  →  median=11.6150s  | acc=93.6437%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->512  | k= 256] times=[15.54, 15.63, 15.74, 15.75, 15.79, 15.79, 15.81, 15.81, 15.85, 15.89]  →  median=15.7900s  | acc=93.7652%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->512  | k= 512] times=[20.32, 20.47, 21.42, 21.67, 21.7, 21.72, 21.73, 21.79, 21.82, 21.84]  →  median=21.7100s  | acc=93.7652%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->512  | k=1024] times=[27.79, 27.82, 27.91, 27.96, 28.31, 28.39, 28.76, 29.05, 29.07, 29.66]  →  median=28.3500s  | acc=93.7652%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->1024 | k=   4] times=[5.95, 6.04, 6.04, 6.13, 6.14, 6.16, 6.18, 6.2, 6.2, 6.24]  →  median=6.1500s  | acc=92.3077%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->1024 | k=   8] times=[6.39, 6.4, 6.4, 6.41, 6.43, 6.45, 6.46, 6.52, 6.53, 6.64]  →  median=6.4400s  | acc=93.2389%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->1024 | k=  16] times=[7.0, 7.0, 7.07, 7.09, 7.11, 7.14, 7.21, 7.22, 7.22, 7.24]  →  median=7.1250s  | acc=93.6437%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->1024 | k=  32] times=[8.23, 8.23, 8.35, 8.38, 8.38, 8.39, 8.4, 8.44, 8.46, 8.47]  →  median=8.3850s  | acc=93.9676%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->1024 | k=  64] times=[10.31, 10.33, 10.4, 10.4, 10.43, 10.44, 10.47, 10.48, 10.53, 10.63]  →  median=10.4350s  | acc=94.0486%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->1024 | k= 128] times=[14.04, 14.12, 14.14, 14.15, 14.19, 14.24, 14.27, 14.31, 14.36, 14.44]  →  median=14.2150s  | acc=94.2915%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->1024 | k= 256] times=[20.13, 20.17, 20.21, 20.25, 20.31, 20.48, 20.48, 20.54, 20.6, 20.62]  →  median=20.3950s  | acc=94.4130%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->1024 | k= 512] times=[29.04, 29.27, 29.31, 29.41, 29.43, 29.43, 29.68, 29.72, 29.75, 29.82]  →  median=29.4300s  | acc=94.4130%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->1024 | k=1024] times=[40.79, 40.88, 41.18, 41.6, 41.64, 42.01, 42.03, 42.14, 42.43, 42.47]  →  median=41.8250s  | acc=94.4534%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->2048 | k=   4] times=[6.11, 6.11, 6.23, 6.25, 6.25, 6.25, 6.27, 6.34, 6.37, 6.41]  →  median=6.2500s  | acc=92.3077%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->2048 | k=   8] times=[6.39, 6.43, 6.47, 6.49, 6.52, 6.6, 6.63, 6.65, 6.66, 6.72]  →  median=6.5600s  | acc=93.2389%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->2048 | k=  16] times=[7.19, 7.26, 7.28, 7.33, 7.38, 7.4, 7.4, 7.41, 7.46, 7.5]  →  median=7.3900s  | acc=93.8866%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->2048 | k=  32] times=[8.72, 8.74, 8.79, 8.85, 8.87, 8.88, 8.95, 8.97, 8.99, 9.07]  →  median=8.8750s  | acc=94.2510%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->2048 | k=  64] times=[11.46, 11.47, 11.48, 11.49, 11.5, 11.53, 11.6, 11.6, 11.64, 11.66]  →  median=11.5150s  | acc=94.4130%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->2048 | k= 128] times=[16.17, 16.2, 16.32, 16.38, 16.42, 16.43, 16.44, 16.47, 16.55, 16.57]  →  median=16.4250s  | acc=94.6559%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->2048 | k= 256] times=[24.02, 24.13, 24.21, 24.31, 24.32, 24.38, 24.43, 24.6, 24.61, 24.73]  →  median=24.3500s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->2048 | k= 512] times=[34.82, 34.83, 34.89, 34.94, 35.13, 35.25, 35.48, 35.5, 35.67, 35.71]  →  median=35.1900s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->2048 | k=1024] times=[53.35, 53.99, 54.04, 56.01, 56.29, 56.38, 56.6, 56.62, 57.05, 57.35]  →  median=56.3350s  | acc=94.7773%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->3584 | k=   4] times=[6.43, 6.57, 6.58, 6.6, 6.61, 6.61, 6.62, 6.63, 6.7, 6.73]  →  median=6.6100s  | acc=92.3077%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->3584 | k=   8] times=[6.62, 6.72, 6.72, 6.78, 6.82, 6.91, 6.94, 6.99, 7.0, 7.02]  →  median=6.8650s  | acc=93.2389%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->3584 | k=  16] times=[7.27, 7.36, 7.37, 7.39, 7.41, 7.49, 7.54, 7.57, 7.61, 7.73]  →  median=7.4500s  | acc=93.8866%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->3584 | k=  32] times=[8.85, 8.93, 8.99, 9.0, 9.03, 9.08, 9.22, 9.23, 9.27, 9.35]  →  median=9.0550s  | acc=94.2915%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->3584 | k=  64] times=[12.11, 12.11, 12.13, 12.16, 12.17, 12.18, 12.21, 12.23, 12.24, 12.35]  →  median=12.1750s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->3584 | k= 128] times=[17.33, 17.5, 17.51, 17.61, 17.63, 17.67, 17.74, 17.79, 17.8, 17.83]  →  median=17.6500s  | acc=94.7368%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->3584 | k= 256] times=[26.69, 26.72, 26.74, 26.77, 26.77, 26.82, 26.84, 26.85, 26.89, 26.91]  →  median=26.7950s  | acc=94.8988%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->3584 | k= 512] times=[42.37, 42.42, 42.52, 42.63, 42.84, 42.88, 42.88, 43.09, 43.18, 43.28]  →  median=42.8600s  | acc=94.9393%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 128->3584 | k=1024] times=[66.71, 66.73, 66.78, 66.9, 66.97, 66.99, 67.11, 67.16, 67.49, 67.87]  →  median=66.9800s  | acc=94.9798%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->512  | k=   4] times=[9.12, 9.19, 9.3, 9.32, 9.32, 9.33, 9.4, 9.43, 9.56, 9.6]  →  median=9.3250s  | acc=93.4818%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->512  | k=   8] times=[9.32, 9.46, 9.51, 9.52, 9.53, 9.53, 9.6, 9.66, 9.68, 9.77]  →  median=9.5300s  | acc=93.6437%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->512  | k=  16] times=[9.72, 9.83, 9.91, 9.97, 10.0, 10.01, 10.04, 10.05, 10.16, 10.31]  →  median=10.0050s  | acc=93.7247%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->512  | k=  32] times=[10.59, 10.61, 10.64, 10.67, 10.7, 10.73, 10.76, 10.83, 10.84, 10.95]  →  median=10.7150s  | acc=93.7652%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->512  | k=  64] times=[11.83, 11.95, 11.95, 11.97, 11.98, 11.98, 12.05, 12.11, 12.14, 12.17]  →  median=11.9800s  | acc=93.8057%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->512  | k= 128] times=[14.13, 14.14, 14.15, 14.16, 14.47, 14.48, 14.5, 14.55, 14.63, 14.63]  →  median=14.4750s  | acc=93.8057%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->512  | k= 256] times=[17.51, 17.68, 17.69, 17.72, 17.73, 17.77, 17.79, 17.82, 17.89, 18.6]  →  median=17.7500s  | acc=93.8057%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->512  | k= 512] times=[21.56, 21.84, 21.88, 21.99, 23.02, 23.03, 23.04, 23.21, 23.31, 23.58]  →  median=23.0250s  | acc=93.8057%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->512  | k=1024] times=[27.81, 27.9, 27.9, 27.92, 27.93, 27.98, 28.04, 28.08, 28.09, 28.12]  →  median=27.9550s  | acc=93.8057%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->1024 | k=   4] times=[9.77, 9.8, 9.82, 9.82, 9.85, 9.87, 9.89, 9.9, 9.91, 9.97]  →  median=9.8600s  | acc=94.1296%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->1024 | k=   8] times=[10.14, 10.17, 10.27, 10.27, 10.29, 10.35, 10.35, 10.37, 10.4, 10.4]  →  median=10.3200s  | acc=94.3320%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->1024 | k=  16] times=[10.82, 10.97, 11.01, 11.02, 11.02, 11.03, 11.04, 11.06, 11.06, 11.1]  →  median=11.0250s  | acc=94.3320%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->1024 | k=  32] times=[12.41, 12.43, 12.44, 12.46, 12.51, 12.51, 12.52, 12.56, 12.58, 12.64]  →  median=12.5100s  | acc=94.4130%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->1024 | k=  64] times=[14.96, 15.06, 15.07, 15.09, 15.12, 15.15, 15.18, 15.24, 15.3, 15.34]  →  median=15.1350s  | acc=94.4534%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->1024 | k= 128] times=[19.03, 19.58, 19.61, 19.65, 19.67, 19.72, 19.79, 19.82, 20.04, 20.04]  →  median=19.6950s  | acc=94.4534%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->1024 | k= 256] times=[26.8, 26.83, 26.9, 27.0, 27.0, 27.11, 27.12, 27.25, 27.27, 27.43]  →  median=27.0550s  | acc=94.4534%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json

# %% [markdown]
# #### Continue Run 2

# %%
if os.path.exists(JSON_PATH):
    with open(JSON_PATH) as f:
        prog_stats = {tuple(map(int, k.strip("()").split(","))): v
                      for k, v in json.load(f).items()}
    print(f"↩️  loaded {len(prog_stats)} scenarios from {JSON_NAME}")
# Out:
# ↩️  loaded 115 scenarios from progressive_knn_medians.json

# %%
print(prog_stats)
# Out:
# {(64, 128, 4): {'accuracy_pct': 83.7247, 'median_time_s': 4.04}, (64, 128, 8): {'accuracy_pct': 85.2227, 'median_time_s': 4.07}, (64, 128, 16): {'accuracy_pct': 86.4372, 'median_time_s': 4.29}, (64, 128, 32): {'accuracy_pct': 87.247, 'median_time_s': 4.75}, (64, 128, 64): {'accuracy_pct': 87.8947, 'median_time_s': 5.475}, (64, 128, 128): {'accuracy_pct': 88.502, 'median_time_s': 6.51}, (64, 128, 256): {'accuracy_pct': 88.583, 'median_time_s': 8.105}, (64, 128, 512): {'accuracy_pct': 88.7449, 'median_time_s': 9.345}, (64, 128, 1024): {'accuracy_pct': 88.7449, 'median_time_s': 12.995}, (64, 256, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.04}, (64, 256, 8): {'accuracy_pct': 86.6397, 'median_time_s': 4.23}, (64, 256, 16): {'accuracy_pct': 88.4211, 'median_time_s': 4.51}, (64, 256, 32): {'accuracy_pct': 89.7571, 'median_time_s': 5.14}, (64, 256, 64): {'accuracy_pct': 90.5263, 'median_time_s': 6.19}, (64, 256, 128): {'accuracy_pct': 91.5385, 'median_time_s': 7.83}, (64, 256, 256): {'accuracy_pct': 91.9838, 'median_time_s': 10.655}, (64, 256, 512): {'accuracy_pct': 92.4696, 'median_time_s': 14.595}, (64, 256, 1024): {'accuracy_pct': 92.6721, 'median_time_s': 19.94}, (64, 512, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.11}, (64, 512, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.31}, (64, 512, 16): {'accuracy_pct': 88.7854, 'median_time_s': 4.72}, (64, 512, 32): {'accuracy_pct': 90.1215, 'median_time_s': 5.605}, (64, 512, 64): {'accuracy_pct': 91.0526, 'median_time_s': 7.05}, (64, 512, 128): {'accuracy_pct': 92.1457, 'median_time_s': 9.36}, (64, 512, 256): {'accuracy_pct': 92.7126, 'median_time_s': 13.21}, (64, 512, 512): {'accuracy_pct': 93.3198, 'median_time_s': 19.04}, (64, 512, 1024): {'accuracy_pct': 93.5628, 'median_time_s': 27.21}, (64, 1024, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.39}, (64, 1024, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.595}, (64, 1024, 16): {'accuracy_pct': 89.1498, 'median_time_s': 5.085}, (64, 1024, 32): {'accuracy_pct': 90.5263, 'median_time_s': 6.015}, (64, 1024, 64): {'accuracy_pct': 91.498, 'median_time_s': 7.82}, (64, 1024, 128): {'accuracy_pct': 92.6316, 'median_time_s': 10.495}, (64, 1024, 256): {'accuracy_pct': 93.2794, 'median_time_s': 13.915}, (64, 1024, 512): {'accuracy_pct': 93.9271, 'median_time_s': 20.76}, (64, 1024, 1024): {'accuracy_pct': 94.2105, 'median_time_s': 33.725}, (64, 2048, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.395}, (64, 2048, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.635}, (64, 2048, 16): {'accuracy_pct': 89.1498, 'median_time_s': 4.935}, (64, 2048, 32): {'accuracy_pct': 90.7287, 'median_time_s': 5.975}, (64, 2048, 64): {'accuracy_pct': 91.7409, 'median_time_s': 7.69}, (64, 2048, 128): {'accuracy_pct': 92.7935, 'median_time_s': 10.735}, (64, 2048, 256): {'accuracy_pct': 93.5223, 'median_time_s': 17.36}, (64, 2048, 512): {'accuracy_pct': 94.2105, 'median_time_s': 25.165}, (64, 2048, 1024): {'accuracy_pct': 94.6154, 'median_time_s': 42.135}, (64, 3584, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.66}, (64, 3584, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.92}, (64, 3584, 16): {'accuracy_pct': 89.1498, 'median_time_s': 5.41}, (64, 3584, 32): {'accuracy_pct': 90.7287, 'median_time_s': 6.49}, (64, 3584, 64): {'accuracy_pct': 91.7409, 'median_time_s': 8.69}, (64, 3584, 128): {'accuracy_pct': 92.834, 'median_time_s': 12.675}, (64, 3584, 256): {'accuracy_pct': 93.6032, 'median_time_s': 19.025}, (64, 3584, 512): {'accuracy_pct': 94.332, 'median_time_s': 31.17}, (64, 3584, 1024): {'accuracy_pct': 94.7368, 'median_time_s': 49.76}, (128, 256, 4): {'accuracy_pct': 92.2267, 'median_time_s': 5.815}, (128, 256, 8): {'accuracy_pct': 92.3077, 'median_time_s': 5.93}, (128, 256, 16): {'accuracy_pct': 92.5506, 'median_time_s': 6.225}, (128, 256, 32): {'accuracy_pct': 92.5911, 'median_time_s': 6.55}, (128, 256, 64): {'accuracy_pct': 92.6721, 'median_time_s': 7.525}, (128, 256, 128): {'accuracy_pct': 92.7935, 'median_time_s': 8.935}, (128, 256, ...

# %%
for startD in dim_grid:
    for maxD in dim_grid:
        if startD >= maxD:         # strictly ascending
            continue
        for k0 in start_k_ls:
            key = (startD, maxD, k0)
            if key in prog_stats:  # already done or ingested
                continue

            times, accs = [], []
            for _ in range(10):
                res = progressive_knn_sklearn(
                    ds_embs     = dataset_embs,
                    qs_embs     = question_embs,
                    df_dataset  = df_dataset,
                    contexts    = contexts,
                    start_dim   = startD,
                    start_k     = k0,
                    max_dim     = maxD,
                    step_factor = 2,
                    step_k      = 2,
                    step_add    = None,
                    verbose     = False
                )
                times.append(res["t_total_s"])
                accs.append(res["accuracy_pct"])
                gc.collect()

            times_sorted = sorted(round(t, 4) for t in times)
            median_time  = round(float(np.median(times_sorted)), 4)
            acc_unique   = set(accs)
            if len(acc_unique) != 1:
                print(f"accuracy drift at [{startD:4d}->{maxD:<4d} | k={k0:4d}]")
            acc_final = round(accs[0], 4)

            # ---- identical print format to your original ---------
            print(f"[{startD:4d}->{maxD:<4d} | k={k0:4d}] "
                  f"times={times_sorted}  →  median={median_time:.4f}s  "
                  f"| acc={acc_final:.4f}%")

            prog_stats[key] = {
                "accuracy_pct" : acc_final,
                "median_time_s": median_time,
                # "times_s"      : times_sorted
            }
            save_json(prog_stats, JSON_NAME)   # overwrite after each scenario

# ==============================================================
print("\n=== MEDIAN TIMES (s) ===")
for (sD, mD, k0), st in sorted(prog_stats.items()):
    print(f"{sD:4}->{mD:<4}  k={k0:4} | "
          f"{st['accuracy_pct']:7.4f}%  | {st['median_time_s']:8.4f}s")
# Out:
# [ 256->1024 | k= 512] times=[36.38, 36.48, 36.84, 36.9, 36.92, 36.93, 37.03, 37.1, 37.12, 37.12]  →  median=36.9250s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->1024 | k=1024] times=[48.37, 48.42, 48.65, 48.81, 48.87, 48.91, 49.04, 49.11, 49.22, 49.3]  →  median=48.8900s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->2048 | k=   4] times=[9.79, 9.88, 9.93, 9.96, 9.96, 9.97, 9.99, 10.03, 10.05, 10.07]  →  median=9.9650s  | acc=94.1296%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->2048 | k=   8] times=[10.26, 10.33, 10.39, 10.43, 10.44, 10.52, 10.57, 10.57, 10.58, 10.63]  →  median=10.4800s  | acc=94.7368%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->2048 | k=  16] times=[11.49, 11.49, 11.51, 11.52, 11.59, 11.6, 11.62, 11.62, 11.67, 11.68]  →  median=11.5950s  | acc=94.7368%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->2048 | k=  32] times=[13.63, 13.69, 13.72, 13.73, 13.74, 13.83, 13.84, 13.86, 13.87, 13.89]  →  median=13.7850s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->2048 | k=  64] times=[17.58, 17.6, 17.62, 17.65, 17.67, 17.67, 17.74, 17.77, 17.8, 17.82]  →  median=17.6700s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->2048 | k= 128] times=[24.16, 24.18, 24.22, 24.29, 24.31, 24.37, 24.38, 24.57, 24.58, 24.6]  →  median=24.3400s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->2048 | k= 256] times=[35.55, 35.56, 35.63, 35.71, 35.75, 35.82, 35.94, 36.24, 36.32, 36.45]  →  median=35.7850s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->2048 | k= 512] times=[52.3, 52.35, 52.42, 52.42, 52.43, 52.45, 52.48, 52.67, 52.7, 53.08]  →  median=52.4400s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->2048 | k=1024] times=[74.35, 74.69, 75.3, 75.33, 75.38, 75.5, 75.62, 75.78, 75.84, 76.14]  →  median=75.4400s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->3584 | k=   4] times=[9.99, 10.09, 10.15, 10.15, 10.18, 10.19, 10.21, 10.22, 10.34, 10.39]  →  median=10.1850s  | acc=94.1296%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->3584 | k=   8] times=[10.4, 10.61, 10.62, 10.69, 10.7, 10.72, 10.76, 10.77, 10.78, 10.8]  →  median=10.7100s  | acc=94.7368%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->3584 | k=  16] times=[12.01, 12.04, 12.04, 12.06, 12.15, 12.18, 12.2, 12.27, 12.29, 12.46]  →  median=12.1650s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->3584 | k=  32] times=[14.46, 14.48, 14.49, 14.52, 14.62, 14.64, 14.64, 14.66, 14.76, 14.84]  →  median=14.6300s  | acc=94.9393%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->3584 | k=  64] times=[18.81, 18.9, 18.95, 19.12, 19.15, 19.16, 19.44, 19.48, 19.49, 19.56]  →  median=19.1550s  | acc=94.9798%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->3584 | k= 128] times=[27.44, 27.47, 27.48, 27.51, 27.51, 27.54, 27.56, 27.59, 27.66, 27.84]  →  median=27.5250s  | acc=94.9798%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->3584 | k= 256] times=[41.35, 41.43, 41.62, 41.75, 41.96, 41.97, 42.04, 42.15, 42.2, 42.47]  →  median=41.9650s  | acc=94.9798%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->3584 | k= 512] times=[64.75, 64.85, 64.99, 65.21, 65.31, 65.34, 65.42, 65.55, 65.64, 65.71]  →  median=65.3250s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 256->3584 | k=1024] times=[97.83, 98.11, 98.61, 99.22, 99.24, 99.3, 99.63, 99.75, 100.13, 100.52]  →  median=99.2700s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->1024 | k=   4] times=[17.11, 17.21, 17.21, 17.22, 17.24, 17.24, 17.29, 17.42, 17.65, 17.67]  →  median=17.2400s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->1024 | k=   8] times=[17.26, 17.41, 17.49, 17.56, 17.62, 17.68, 17.71, 17.72, 17.82, 17.91]  →  median=17.6500s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->1024 | k=  16] times=[18.04, 18.17, 18.33, 18.57, 18.62, 18.64, 18.68, 18.69, 18.72, 18.76]  →  median=18.6300s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->1024 | k=  32] times=[18.96, 19.19, 19.2, 19.35, 19.37, 19.48, 19.5, 19.78, 20.0, 20.0]  →  median=19.4250s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->1024 | k=  64] times=[21.4, 21.45, 21.46, 21.48, 21.75, 21.76, 21.79, 21.84, 22.05, 22.07]  →  median=21.7550s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->1024 | k= 128] times=[25.34, 25.42, 25.45, 25.46, 25.66, 25.76, 25.76, 25.87, 26.11, 26.15]  →  median=25.7100s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->1024 | k= 256] times=[31.03, 31.07, 31.23, 31.29, 31.48, 31.58, 31.64, 32.05, 32.07, 32.16]  →  median=31.5300s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->1024 | k= 512] times=[38.82, 39.07, 39.09, 39.24, 39.34, 39.36, 39.38, 39.58, 39.74, 39.76]  →  median=39.3500s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->1024 | k=1024] times=[46.84, 46.86, 47.09, 47.13, 47.14, 47.22, 47.27, 47.3, 47.38, 47.51]  →  median=47.1800s  | acc=94.4939%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->2048 | k=   4] times=[17.56, 17.6, 17.61, 17.62, 17.67, 17.72, 17.82, 17.85, 17.9, 18.0]  →  median=17.6950s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->2048 | k=   8] times=[18.09, 18.09, 18.16, 18.29, 18.3, 18.3, 18.33, 18.34, 18.45, 18.65]  →  median=18.3000s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->2048 | k=  16] times=[19.69, 19.71, 19.77, 19.78, 19.8, 19.82, 19.91, 19.94, 20.07, 20.27]  →  median=19.8100s  | acc=94.8988%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->2048 | k=  32] times=[22.05, 22.09, 22.11, 22.13, 22.15, 22.34, 22.35, 22.37, 22.44, 22.51]  →  median=22.2450s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->2048 | k=  64] times=[26.65, 26.78, 26.78, 26.82, 26.88, 27.06, 27.15, 27.21, 27.28, 27.43]  →  median=26.9700s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->2048 | k= 128] times=[34.57, 34.69, 34.7, 34.76, 34.84, 34.87, 34.87, 34.88, 35.0, 35.22]  →  median=34.8550s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->2048 | k= 256] times=[46.41, 46.43, 46.65, 46.88, 46.96, 47.12, 47.21, 47.25, 47.5, 47.85]  →  median=47.0400s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->2048 | k= 512] times=[64.71, 65.6, 65.7, 65.8, 65.86, 65.9, 65.99, 66.05, 66.17, 66.4]  →  median=65.8800s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->2048 | k=1024] times=[88.13, 89.45, 89.84, 89.91, 92.76, 93.1, 93.35, 93.66, 94.33, 94.78]  →  median=92.9300s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->3584 | k=   4] times=[17.94, 17.94, 17.98, 18.0, 18.07, 18.12, 18.13, 18.17, 18.18, 18.25]  →  median=18.0950s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->3584 | k=   8] times=[18.58, 18.71, 18.71, 18.74, 18.78, 18.83, 18.85, 18.86, 18.9, 18.9]  →  median=18.8050s  | acc=94.9393%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->3584 | k=  16] times=[20.27, 20.38, 20.53, 20.59, 20.63, 20.63, 20.64, 20.68, 20.69, 20.72]  →  median=20.6300s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->3584 | k=  32] times=[23.85, 23.87, 23.92, 23.96, 24.11, 24.21, 24.24, 24.29, 24.43, 24.47]  →  median=24.1600s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->3584 | k=  64] times=[30.34, 30.34, 30.49, 30.54, 30.58, 30.68, 30.85, 30.88, 31.06, 31.15]  →  median=30.6300s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->3584 | k= 128] times=[41.92, 42.12, 42.32, 42.47, 42.48, 42.5, 42.57, 42.58, 42.8, 43.07]  →  median=42.4900s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->3584 | k= 256] times=[61.36, 61.67, 61.89, 61.93, 61.94, 62.2, 62.25, 62.26, 62.5, 62.74]  →  median=62.0700s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json

# %% [markdown]
# #### Continue Run 3

# %%
if os.path.exists(JSON_PATH):
    with open(JSON_PATH) as f:
        prog_stats = {tuple(map(int, k.strip("()").split(","))): v
                      for k, v in json.load(f).items()}
    print(f"↩️  loaded {len(prog_stats)} scenarios from {JSON_NAME}")
# Out:
# ↩️  loaded 160 scenarios from progressive_knn_medians.json

# %%
print(prog_stats)
# Out:
# {(64, 128, 4): {'accuracy_pct': 83.7247, 'median_time_s': 4.04}, (64, 128, 8): {'accuracy_pct': 85.2227, 'median_time_s': 4.07}, (64, 128, 16): {'accuracy_pct': 86.4372, 'median_time_s': 4.29}, (64, 128, 32): {'accuracy_pct': 87.247, 'median_time_s': 4.75}, (64, 128, 64): {'accuracy_pct': 87.8947, 'median_time_s': 5.475}, (64, 128, 128): {'accuracy_pct': 88.502, 'median_time_s': 6.51}, (64, 128, 256): {'accuracy_pct': 88.583, 'median_time_s': 8.105}, (64, 128, 512): {'accuracy_pct': 88.7449, 'median_time_s': 9.345}, (64, 128, 1024): {'accuracy_pct': 88.7449, 'median_time_s': 12.995}, (64, 256, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.04}, (64, 256, 8): {'accuracy_pct': 86.6397, 'median_time_s': 4.23}, (64, 256, 16): {'accuracy_pct': 88.4211, 'median_time_s': 4.51}, (64, 256, 32): {'accuracy_pct': 89.7571, 'median_time_s': 5.14}, (64, 256, 64): {'accuracy_pct': 90.5263, 'median_time_s': 6.19}, (64, 256, 128): {'accuracy_pct': 91.5385, 'median_time_s': 7.83}, (64, 256, 256): {'accuracy_pct': 91.9838, 'median_time_s': 10.655}, (64, 256, 512): {'accuracy_pct': 92.4696, 'median_time_s': 14.595}, (64, 256, 1024): {'accuracy_pct': 92.6721, 'median_time_s': 19.94}, (64, 512, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.11}, (64, 512, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.31}, (64, 512, 16): {'accuracy_pct': 88.7854, 'median_time_s': 4.72}, (64, 512, 32): {'accuracy_pct': 90.1215, 'median_time_s': 5.605}, (64, 512, 64): {'accuracy_pct': 91.0526, 'median_time_s': 7.05}, (64, 512, 128): {'accuracy_pct': 92.1457, 'median_time_s': 9.36}, (64, 512, 256): {'accuracy_pct': 92.7126, 'median_time_s': 13.21}, (64, 512, 512): {'accuracy_pct': 93.3198, 'median_time_s': 19.04}, (64, 512, 1024): {'accuracy_pct': 93.5628, 'median_time_s': 27.21}, (64, 1024, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.39}, (64, 1024, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.595}, (64, 1024, 16): {'accuracy_pct': 89.1498, 'median_time_s': 5.085}, (64, 1024, 32): {'accuracy_pct': 90.5263, 'median_time_s': 6.015}, (64, 1024, 64): {'accuracy_pct': 91.498, 'median_time_s': 7.82}, (64, 1024, 128): {'accuracy_pct': 92.6316, 'median_time_s': 10.495}, (64, 1024, 256): {'accuracy_pct': 93.2794, 'median_time_s': 13.915}, (64, 1024, 512): {'accuracy_pct': 93.9271, 'median_time_s': 20.76}, (64, 1024, 1024): {'accuracy_pct': 94.2105, 'median_time_s': 33.725}, (64, 2048, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.395}, (64, 2048, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.635}, (64, 2048, 16): {'accuracy_pct': 89.1498, 'median_time_s': 4.935}, (64, 2048, 32): {'accuracy_pct': 90.7287, 'median_time_s': 5.975}, (64, 2048, 64): {'accuracy_pct': 91.7409, 'median_time_s': 7.69}, (64, 2048, 128): {'accuracy_pct': 92.7935, 'median_time_s': 10.735}, (64, 2048, 256): {'accuracy_pct': 93.5223, 'median_time_s': 17.36}, (64, 2048, 512): {'accuracy_pct': 94.2105, 'median_time_s': 25.165}, (64, 2048, 1024): {'accuracy_pct': 94.6154, 'median_time_s': 42.135}, (64, 3584, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.66}, (64, 3584, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.92}, (64, 3584, 16): {'accuracy_pct': 89.1498, 'median_time_s': 5.41}, (64, 3584, 32): {'accuracy_pct': 90.7287, 'median_time_s': 6.49}, (64, 3584, 64): {'accuracy_pct': 91.7409, 'median_time_s': 8.69}, (64, 3584, 128): {'accuracy_pct': 92.834, 'median_time_s': 12.675}, (64, 3584, 256): {'accuracy_pct': 93.6032, 'median_time_s': 19.025}, (64, 3584, 512): {'accuracy_pct': 94.332, 'median_time_s': 31.17}, (64, 3584, 1024): {'accuracy_pct': 94.7368, 'median_time_s': 49.76}, (128, 256, 4): {'accuracy_pct': 92.2267, 'median_time_s': 5.815}, (128, 256, 8): {'accuracy_pct': 92.3077, 'median_time_s': 5.93}, (128, 256, 16): {'accuracy_pct': 92.5506, 'median_time_s': 6.225}, (128, 256, 32): {'accuracy_pct': 92.5911, 'median_time_s': 6.55}, (128, 256, 64): {'accuracy_pct': 92.6721, 'median_time_s': 7.525}, (128, 256, 128): {'accuracy_pct': 92.7935, 'median_time_s': 8.935}, (128, 256, ...

# %%
for startD in dim_grid:
    for maxD in dim_grid:
        if startD >= maxD:         # strictly ascending
            continue
        for k0 in start_k_ls:
            key = (startD, maxD, k0)
            if key in prog_stats:  # already done or ingested
                continue

            times, accs = [], []
            for _ in range(10):
                res = progressive_knn_sklearn(
                    ds_embs     = dataset_embs,
                    qs_embs     = question_embs,
                    df_dataset  = df_dataset,
                    contexts    = contexts,
                    start_dim   = startD,
                    start_k     = k0,
                    max_dim     = maxD,
                    step_factor = 2,
                    step_k      = 2,
                    step_add    = None,
                    verbose     = False
                )
                times.append(res["t_total_s"])
                accs.append(res["accuracy_pct"])
                gc.collect()

            times_sorted = sorted(round(t, 4) for t in times)
            median_time  = round(float(np.median(times_sorted)), 4)
            acc_unique   = set(accs)
            if len(acc_unique) != 1:
                print(f"accuracy drift at [{startD:4d}->{maxD:<4d} | k={k0:4d}]")
            acc_final = round(accs[0], 4)

            # ---- identical print format to your original ---------
            print(f"[{startD:4d}->{maxD:<4d} | k={k0:4d}] "
                  f"times={times_sorted}  →  median={median_time:.4f}s  "
                  f"| acc={acc_final:.4f}%")

            prog_stats[key] = {
                "accuracy_pct" : acc_final,
                "median_time_s": median_time,
                # "times_s"      : times_sorted
            }
            save_json(prog_stats, JSON_NAME)   # overwrite after each scenario

# ==============================================================
print("\n=== MEDIAN TIMES (s) ===")
for (sD, mD, k0), st in sorted(prog_stats.items()):
    print(f"{sD:4}->{mD:<4}  k={k0:4} | "
          f"{st['accuracy_pct']:7.4f}%  | {st['median_time_s']:8.4f}s")
# Out:
# [ 512->3584 | k= 512] times=[94.48, 94.74, 94.87, 94.95, 95.19, 95.62, 95.99, 95.99, 96.26, 96.43]  →  median=95.4050s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [ 512->3584 | k=1024] times=[130.8, 131.5, 132.29, 132.91, 134.23, 136.68, 137.54, 137.92, 139.25, 139.4]  →  median=135.4550s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->2048 | k=   4] times=[30.72, 30.93, 30.97, 31.09, 31.2, 31.24, 31.31, 31.38, 31.46, 31.76]  →  median=31.2200s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->2048 | k=   8] times=[30.87, 31.24, 31.82, 31.84, 31.88, 31.92, 31.96, 32.01, 32.14, 32.3]  →  median=31.9000s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->2048 | k=  16] times=[32.19, 32.33, 32.47, 32.54, 32.55, 32.56, 32.62, 32.75, 32.75, 32.85]  →  median=32.5550s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->2048 | k=  32] times=[34.82, 34.83, 34.97, 34.98, 35.13, 35.13, 35.14, 35.23, 35.3, 35.34]  →  median=35.1300s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->2048 | k=  64] times=[38.88, 39.04, 39.13, 39.15, 39.3, 39.39, 39.72, 39.73, 39.9, 39.91]  →  median=39.3450s  | acc=94.8583%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->2048 | k= 128] times=[46.41, 46.41, 46.54, 46.59, 46.63, 46.69, 46.73, 46.97, 47.44, 47.49]  →  median=46.6600s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->2048 | k= 256] times=[57.14, 57.3, 57.31, 57.37, 57.67, 58.03, 58.11, 58.26, 58.36, 58.4]  →  median=57.8500s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->2048 | k= 512] times=[71.01, 71.03, 71.07, 71.11, 71.28, 71.32, 71.35, 71.47, 71.58, 71.7]  →  median=71.3000s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->2048 | k=1024] times=[84.1, 84.22, 84.4, 84.43, 84.5, 84.97, 85.0, 85.18, 85.22, 85.81]  →  median=84.7350s  | acc=94.8178%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->3584 | k=   4] times=[30.86, 31.12, 31.26, 31.27, 31.44, 31.45, 31.49, 31.55, 31.72, 31.86]  →  median=31.4450s  | acc=94.9798%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->3584 | k=   8] times=[32.03, 32.15, 32.2, 32.25, 32.25, 32.46, 32.53, 32.55, 32.88, 32.94]  →  median=32.3550s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->3584 | k=  16] times=[34.61, 34.93, 35.04, 35.2, 35.21, 35.38, 35.39, 35.42, 35.51, 35.93]  →  median=35.2950s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->3584 | k=  32] times=[39.73, 39.73, 39.86, 39.9, 39.92, 40.24, 40.27, 40.28, 40.47, 40.49]  →  median=40.0800s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->3584 | k=  64] times=[47.82, 48.07, 48.1, 48.25, 48.26, 48.28, 48.37, 48.4, 48.52, 48.76]  →  median=48.2700s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->3584 | k= 128] times=[62.52, 62.7, 62.92, 63.16, 63.25, 63.38, 63.38, 63.42, 63.49, 63.85]  →  median=63.3150s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->3584 | k= 256] times=[83.81, 83.9, 84.06, 84.07, 84.45, 84.64, 85.93, 86.8, 87.17, 87.61]  →  median=84.5450s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->3584 | k= 512] times=[114.18, 114.37, 114.39, 114.63, 115.0, 115.05, 115.14, 115.24, 115.61, 115.65]  →  median=115.0250s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [1024->3584 | k=1024] times=[148.93, 149.65, 149.83, 150.48, 150.71, 150.9, 151.18, 151.77, 152.04, 154.84]  →  median=150.8050s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [2048->3584 | k=   4] times=[58.46, 58.54, 58.67, 58.71, 58.8, 58.95, 59.17, 59.32, 59.46, 59.47]  →  median=58.8750s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [2048->3584 | k=   8] times=[59.24, 59.46, 59.47, 59.62, 59.81, 59.89, 59.93, 59.94, 59.94, 60.19]  →  median=59.8500s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [2048->3584 | k=  16] times=[61.83, 61.86, 61.88, 61.89, 61.93, 62.1, 62.11, 62.2, 62.35, 62.84]  →  median=62.0150s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [2048->3584 | k=  32] times=[65.53, 65.55, 65.68, 65.8, 66.1, 66.17, 66.69, 67.07, 67.33, 67.44]  →  median=66.1350s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [2048->3584 | k=  64] times=[72.64, 72.84, 73.14, 73.18, 73.25, 73.32, 73.39, 73.59, 73.73, 74.78]  →  median=73.2850s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [2048->3584 | k= 128] times=[83.59, 83.61, 83.75, 84.34, 85.97, 86.2, 86.37, 86.72, 86.76, 87.34]  →  median=86.0850s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [2048->3584 | k= 256] times=[104.49, 104.56, 104.6, 104.82, 104.93, 104.99, 105.26, 105.81, 106.02, 107.56]  →  median=104.9600s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [2048->3584 | k= 512] times=[125.86, 127.7, 129.3, 130.76, 133.4, 133.74, 133.76, 134.67, 135.71, 137.41]  →  median=133.5700s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
# [2048->3584 | k=1024] times=[153.49, 154.15, 155.33, 155.52, 155.7, 156.15, 156.28, 156.41, 157.11, 157.35]  →  median=155.9250s  | acc=95.0202%
# ✔  saved → /content/drive/MyDrive/Colab Notebooks/CMPE 295 RAG System/progressive_knn_medians.json
#
# === MEDIAN TIMES (s) ===
#   64->128   k=   4 | 83.7247%  |   4.0400s
#   64->128   k=   8 | 85.2227%  |   4.0700s
#   64->128   k=  16 | 86.4372%  |   4.2900s
#   64->128   k=  32 | 87.2470%  |   4.7500s
#   64->128   k=  64 | 87.8947%  |   5.4750s
#   64->128   k= 128 | 88.5020%  |   6.5100s
#   64->128   k= 256 | 88.5830%  |   8.1050s
#   64->128   k= 512 | 88.7449%  |   9.3450s
#   64->128   k=1024 | 88.7449%  |  12.9950s
#   64->256   k=   4 | 84.8178%  |   4.0400s
#   64->256   k=   8 | 86.6397%  |   4.2300s
#   64->256   k=  16 | 88.4211%  |   4.5100s
#   64->256   k=  32 | 89.7571%  |   5.1400s
#   64->256   k=  64 | 90.5263%  |   6.1900s
#   64->256   k= 128 | 91.5385%  |   7.8300s
#   64->256   k= 256 | 91.9838%  |  10.6550s
#   64->256   k= 512 | 92.4696%  |  14.5950s
#   64->256   k=1024 | 92.6721%  |  19.9400s
#   64->512   k=   4 | 84.8178%  |   4.1100s
#   64->512   k=   8 | 86.8016%  |   4.3100s
#   64->512   k=  16 | 88.7854%  |   4.7200s
#   64->512   k=  32 | 90.1215%  |   5.6050s
#   64->512   k=  64 | 91.0526%  |   7.0500s
#   64->512   k= 128 | 92.1457%  |   9.3600s
#   64->512   k= 256 | 92.7126%  |  13.2100s
#   64->512   k= 512 | 93.3198%  |  19.0400s
#   64->512   k=1024 | 93.5628%  |  27.2100s
#   64->1024  k=   4 | 84.8178%  |   4.3900s
#   64->1024  k=   8 | 86.8016%  |   4.5950s
#   64->1024  k=  16 | 89.1498%  |   5.0850s
#   64->1024  k=  32 | 90.5263%  |   6.0150s
#   64->1024  k=  64 | 91.4980%  |   7.8200s
#   64->1024  k= 128 | 92.6316%  |  10.4950s
#   64->1024  k= 256 | 93.2794%  |  13.9150s
#   64->1024  k= 512 | 93.9271%  |  20.7600s
#   64->1024  k=1024 | 94.2105%  |  33.7250s
#   64->2048  k=   4 | 84.8178%  |   4.3950s
#   64->2048  k=   8 | 86.8016%  |   4.6350s
#   64->2048  k=  16 | 89.1498%  |   4.9350s
#   64->2048  k=  32 | 90.7287%  |   5.9750s
#   64->2048  k=  64 | 91.7409%  |   7.6900s
#   64->2048  k= 128 | 92.7935%  |  10.7350s
#   64->2048  k= 256 | 93.5223%  |  17.3600s
#   64->2048  k= 512 | 94.2105%  |  25.1650s
#   64->2048  k=1024 | 94.6154%  |  42.1350s
#   64->3584  k=   4 | 84.8178%  |   4.6600s
#   64->3584  k=   8 | 86.8016%  |   4.9200s
#   64->3584  k=  16 | 89.1498%  |   5.4100s
#   64->3584  k=  32 | 90.7287%  |   6.4900s
#   64->3584  k=  64 | 91.7409%  |   8.6900s
#   64->3584  k= 128 | 92.8340%  |  12.6750s
#   64->3584  k= 256 | 93.6032%  |  19.0250s
#   64->3584  k= 512 | 94.3320%  |  31.1700s
#   64->3584  k=1024 | 94.7368%  |  49.7600s
#  128->256   k=   4 | 92.2267%  |   5.8150s
#  128->256   k=   8 | 92.3077%  |   5.9300s
#  128->256   k=  16 | 92.5506%  |   6.2250s
#  128->256   k=  32 | 92.5911%  |   6.5500s
#  128->256   k=  64 | 92.6721%  |   7.5250s
#  128->256   k= 128 | 92.7935%  |   8.9350s
#  128->256   k= 256 | 92.7935%  |  10.8250s
#  128->256   k= 512 | 92.7935%  |  13.4050s
#  128->256   k=1024 | 92.7935%  |  16.5750s
#  128->512   k=   4 | 92.3077%  |   6.0600s
#  128->512   k=   8 | 92.7126%  |   6.2600s
#  128->512   k=  16 | 93.1174%  |   6.7250s
#  128->512   k=  32 | 93.4008%  |   7.5500s
#  128->512   k=  64 | 93.4818%  |   9.0900s
#  128->512   k= 128 | 93.6437%  |  11.6150s
#  128->512   k= 256 | 93.7652%  |  15.7900s
#  128->512   k= 512 | 93.7652%  |  21.7100s
#  128->512   k=1024 | 93.7652%  |  28.3500s
#  128->1024  k=   4 | 92.3077%  |   6.1500s
#  128->1024  k=   8 | 93.2389%  |   6.4400s
#  128->1024  k=  16 | 93.6437%  |   7.1250s
#  128->1024  k=  32 | 93.9676%  |   8.3850s
#  128->1024  k=  64 | 94.0486%  |  10.4350s
#  128->1024  k= 128 | 94.2915%  |  14.2150s
#  128->1024  k= 256 | 94.4130%  |  20.3950s
#  128->1024  k= 512 | 94.4130%  |  29.4300s
#  128->1024  k=1024 | 94.4534%  |  41.8250s
#  128->2048  k=   4 | 92.3077%  |   6.2500s
#  128->2048  k=   8 | 93.2389%  |   6.5600s
#  128->2048  k=  16 | 93.8866%  |   7.3900s
#  128->2048  k=  32 | 94.2510%  |   8.8750s
#  128->2048  k=  64 | 94.4130%  |  11.5150s
#  128->2048  k= 128 | 94.6559%  |  16.4250s
#  128->2048  k= 256 | 94.8178%  |  24.3500s
#  128->2048  k= 512 | 94.8178%  |  35.1900s
#  128->2048  k=1024 | 94.7773%  |  56.3350s
#  128->3584  k=   4 | 92.3077%  |   6.6100s
#  128->3584  k=   8 | 93.2389%  |   6.8650s
#  128->3584  k=  16 | 93.8866%  |   7.4500s
#  128->3584  k=  32 | 94.2915%  |   9.0550s
#  128->3584  k=  64 | 94.4939%  |  12.1750s
#  128->3584  k= 128 | 94.7368%  |  17.6500s
#  128->3584  k= 256 | 94.8988%  |  26.7950s
#  128->3584  k= 512 | 94.9393%  |  42.8600s
#  128->3584  k=1024 | 94.9798%  |  66.9800s
#  256->512   k=   4 | 93.4818%  |   9.3250s
#  256->512   k=   8 | 93.6437%  |   9.5300s
#  256->512   k=  16 | 93.7247%  |  10.0050s
#  256->512   k=  32 | 93.7652%  |  10.7150s
#  256->512   k=  64 | 93.8057%  |  11.9800s
#  256->512   k= 128 | 93.8057%  |  14.4750s
#  256->512   k= 256 | 93.8057%  |  17.7500s
#  256->512   k= 512 | 93.8057%  |  23.0250s
#  256->512   k=1024 | 93.8057%  |  27.9550s
#  256->1024  k=   4 | 94.1296%  |   9.8600s
#  256->1024  k=   8 | 94.3320%  |  10.3200s
#  256->1024  k=  16 | 94.3320%  |  11.0250s
#  256->1024  k=  32 | 94.4130%  |  12.5100s
#  256->1024  k=  64 | 94.4534%  |  15.1350s
#  256->1024  k= 128 | 94.4534%  |  19.6950s
#  256->1024  k= 256 | 94.4534%  |  27.0550s
#  256->1024  k= 512 | 94.4939%  |  36.9250s
#  256->1024  k=1024 | 94.4939%  |  48.8900s
#  256->2048  k=   4 | 94.1296%  |   9.9650s
#  256->2048  k=   8 | 94.7368%  |  10.4800s
#  256->2048  k=  16 | 94.7368%  |  11.5950s
#  256->2048  k=  32 | 94.8178%  |  13.7850s
#  256->2048  k=  64 | 94.8583%  |  17.6700s
#  256->2048  k= 128 | 94.8178%  |  24.3400s
#  256->2048  k= 256 | 94.8178%  |  35.7850s
#  256->2048  k= 512 | 94.8178%  |  52.4400s
#  256->2048  k=1024 | 94.8178%  |  75.4400s
#  256->3584  k=   4 | 94.1296%  |  10.1850s
#  256->3584  k=   8 | 94.7368%  |  10.7100s
#  256->3584  k=  16 | 94.8178%  |  12.1650s
#  256->3584  k=  32 | 94.9393%  |  14.6300s
#  256->3584  k=  64 | 94.9798%  |  19.1550s
#  256->3584  k= 128 | 94.9798%  |  27.5250s
#  256->3584  k= 256 | 94.9798%  |  41.9650s
#  256->3584  k= 512 | 95.0202%  |  65.3250s
#  256->3584  k=1024 | 95.0202%  |  99.2700s
#  512->1024  k=   4 | 94.4939%  |  17.2400s
#  512->1024  k=   8 | 94.4939%  |  17.6500s
#  512->1024  k=  16 | 94.4939%  |  18.6300s
#  512->1024  k=  32 | 94.4939%  |  19.4250s
#  512->1024  k=  64 | 94.4939%  |  21.7550s
#  512->1024  k= 128 | 94.4939%  |  25.7100s
#  512->1024  k= 256 | 94.4939%  |  31.5300s
#  512->1024  k= 512 | 94.4939%  |  39.3500s
#  512->1024  k=1024 | 94.4939%  |  47.1800s
#  512->2048  k=   4 | 94.8583%  |  17.6950s
#  512->2048  k=   8 | 94.8583%  |  18.3000s
#  512->2048  k=  16 | 94.8988%  |  19.8100s
#  512->2048  k=  32 | 94.8583%  |  22.2450s
#  512->2048  k=  64 | 94.8583%  |  26.9700s
#  512->2048  k= 128 | 94.8583%  |  34.8550s
#  512->2048  k= 256 | 94.8178%  |  47.0400s
#  512->2048  k= 512 | 94.8178%  |  65.8800s
#  512->2048  k=1024 | 94.8178%  |  92.9300s
#  512->3584  k=   4 | 94.8583%  |  18.0950s
#  512->3584  k=   8 | 94.9393%  |  18.8050s
#  512->3584  k=  16 | 95.0202%  |  20.6300s
#  512->3584  k=  32 | 95.0202%  |  24.1600s
#  512->3584  k=  64 | 95.0202%  |  30.6300s
#  512->3584  k= 128 | 95.0202%  |  42.4900s
#  512->3584  k= 256 | 95.0202%  |  62.0700s
#  512->3584  k= 512 | 95.0202%  |  95.4050s
#  512->3584  k=1024 | 95.0202%  | 135.4550s
# 1024->2048  k=   4 | 94.8583%  |  31.2200s
# 1024->2048  k=   8 | 94.8583%  |  31.9000s
# 1024->2048  k=  16 | 94.8583%  |  32.5550s
# 1024->2048  k=  32 | 94.8583%  |  35.1300s
# 1024->2048  k=  64 | 94.8583%  |  39.3450s
# 1024->2048  k= 128 | 94.8178%  |  46.6600s
# 1024->2048  k= 256 | 94.8178%  |  57.8500s
# 1024->2048  k= 512 | 94.8178%  |  71.3000s
# 1024->2048  k=1024 | 94.8178%  |  84.7350s
# 1024->3584  k=   4 | 94.9798%  |  31.4450s
# 1024->3584  k=   8 | 95.0202%  |  32.3550s
# 1024->3584  k=  16 | 95.0202%  |  35.2950s
# 1024->3584  k=  32 | 95.0202%  |  40.0800s
# 1024->3584  k=  64 | 95.0202%  |  48.2700s
# 1024->3584  k= 128 | 95.0202%  |  63.3150s
# 1024->3584  k= 256 | 95.0202%  |  84.5450s
# 1024->3584  k= 512 | 95.0202%  | 115.0250s
# 1024->3584  k=1024 | 95.0202%  | 150.8050s
# 2048->3584  k=   4 | 95.0202%  |  58.8750s
# 2048->3584  k=   8 | 95.0202%  |  59.8500s
# 2048->3584  k=  16 | 95.0202%  |  62.0150s
# 2048->3584  k=  32 | 95.0202%  |  66.1350s
# 2048->3584  k=  64 | 95.0202%  |  73.2850s
# 2048->3584  k= 128 | 95.0202%  |  86.0850s
# 2048->3584  k= 256 | 95.0202%  | 104.9600s
# 2048->3584  k= 512 | 95.0202%  | 133.5700s
# 2048->3584  k=1024 | 95.0202%  | 155.9250s

# %%
len(prog_stats)
# Out:
# 189

# %% [markdown]
# # Plot

# %% [markdown]
# ## Overall

# %%
original_trunc_knn = {}
progressive_trunc_knn = {}

# %%
def load_json(json_path):
  with open(json_path) as f:
    return {tuple(map(int, k.strip("()").split(","))): v
            for k, v in json.load(f).items()}

# %%
progress_trunc_knn_json  = "progressive_knn_medians.json"
original_trunc_knn_json = "truncate_first_knn_medians.json"
progress_trunc_knn_json_path  = f"{drive_root}/{progress_trunc_knn_json}"
original_trunc_knn_json_path = f"{drive_root}/{original_trunc_knn_json}"

original_trunc_knn = load_json(original_trunc_knn_json_path)
progressive_trunc_knn = load_json(progress_trunc_knn_json_path)

# %%
print(original_trunc_knn)
# Out:
# {(3584,): {'accuracy_pct': 95.0202, 'median_time_s': 99.3581}, (3072,): {'accuracy_pct': 94.9798, 'median_time_s': 87.5013}, (2048,): {'accuracy_pct': 94.8178, 'median_time_s': 57.4883}, (1024,): {'accuracy_pct': 94.4939, 'median_time_s': 29.6964}, (512,): {'accuracy_pct': 93.8057, 'median_time_s': 16.4421}, (504,): {'accuracy_pct': 93.8866, 'median_time_s': 15.7597}, (496,): {'accuracy_pct': 93.8057, 'median_time_s': 15.6233}, (488,): {'accuracy_pct': 93.7652, 'median_time_s': 15.3404}, (480,): {'accuracy_pct': 93.7247, 'median_time_s': 15.0536}, (472,): {'accuracy_pct': 93.7652, 'median_time_s': 14.7977}, (464,): {'accuracy_pct': 93.8057, 'median_time_s': 14.7158}, (456,): {'accuracy_pct': 93.7652, 'median_time_s': 14.5692}, (448,): {'accuracy_pct': 93.6842, 'median_time_s': 14.3969}, (440,): {'accuracy_pct': 93.5628, 'median_time_s': 14.2381}, (432,): {'accuracy_pct': 93.5223, 'median_time_s': 13.9428}, (424,): {'accuracy_pct': 93.6032, 'median_time_s': 14.0046}, (416,): {'accuracy_pct': 93.6032, 'median_time_s': 13.6727}, (408,): {'accuracy_pct': 93.5628, 'median_time_s': 13.5728}, (400,): {'accuracy_pct': 93.6032, 'median_time_s': 13.3905}, (392,): {'accuracy_pct': 93.5223, 'median_time_s': 13.0533}, (384,): {'accuracy_pct': 93.4008, 'median_time_s': 12.8413}, (376,): {'accuracy_pct': 93.2794, 'median_time_s': 12.4153}, (368,): {'accuracy_pct': 93.2794, 'median_time_s': 12.0985}, (360,): {'accuracy_pct': 93.2389, 'median_time_s': 11.9688}, (352,): {'accuracy_pct': 93.1579, 'median_time_s': 11.7205}, (344,): {'accuracy_pct': 92.9555, 'median_time_s': 11.5171}, (336,): {'accuracy_pct': 92.8745, 'median_time_s': 11.3801}, (328,): {'accuracy_pct': 92.8745, 'median_time_s': 11.1568}, (320,): {'accuracy_pct': 92.7126, 'median_time_s': 10.8814}, (312,): {'accuracy_pct': 92.5911, 'median_time_s': 10.7416}, (304,): {'accuracy_pct': 92.3887, 'median_time_s': 10.5377}, (296,): {'accuracy_pct': 92.5506, 'median_time_s': 10.4184}, (288,): {'accuracy_pct': 93.0769, 'median_time_s': 10.1855}, (280,): {'accuracy_pct': 93.1579, 'median_time_s': 9.9632}, (272,): {'accuracy_pct': 92.9555, 'median_time_s': 9.7931}, (264,): {'accuracy_pct': 93.0364, 'median_time_s': 9.5435}, (256,): {'accuracy_pct': 92.7935, 'median_time_s': 9.3839}, (248,): {'accuracy_pct': 92.8745, 'median_time_s': 9.1377}, (240,): {'accuracy_pct': 92.5911, 'median_time_s': 8.9192}, (232,): {'accuracy_pct': 92.4291, 'median_time_s': 8.5756}, (224,): {'accuracy_pct': 92.2267, 'median_time_s': 8.535}, (216,): {'accuracy_pct': 91.9838, 'median_time_s': 8.1986}, (208,): {'accuracy_pct': 91.8623, 'median_time_s': 7.9734}, (200,): {'accuracy_pct': 91.7409, 'median_time_s': 7.6921}, (192,): {'accuracy_pct': 91.5789, 'median_time_s': 7.4458}, (184,): {'accuracy_pct': 91.3765, 'median_time_s': 7.2308}, (176,): {'accuracy_pct': 91.0526, 'median_time_s': 6.9511}, (168,): {'accuracy_pct': 90.8502, 'median_time_s': 6.8448}, (160,): {'accuracy_pct': 90.6073, 'median_time_s': 6.6011}, (152,): {'accuracy_pct': 90.081, 'median_time_s': 6.3164}, (144,): {'accuracy_pct': 89.6356, 'median_time_s': 6.1132}, (136,): {'accuracy_pct': 89.5547, 'median_time_s': 5.8922}, (128,): {'accuracy_pct': 88.7854, 'median_time_s': 5.7095}, (120,): {'accuracy_pct': 88.3806, 'median_time_s': 5.4877}, (112,): {'accuracy_pct': 87.8543, 'median_time_s': 5.1778}, (104,): {'accuracy_pct': 86.5587, 'median_time_s': 5.0233}, (96,): {'accuracy_pct': 84.9798, 'median_time_s': 4.8325}, (88,): {'accuracy_pct': 83.1579, 'median_time_s': 4.5491}, (80,): {'accuracy_pct': 80.5263, 'median_time_s': 4.3103}, (72,): {'accuracy_pct': 76.8826, 'median_time_s': 4.168}, (64,): {'accuracy_pct': 78.4211, 'median_time_s': 3.8344}, (56,): {'accuracy_pct': 71.7814, 'median_time_s': 3.6586}, (48,): {'accuracy_pct': 62.7126, 'median_time_s': 3.4405}, (40,): {'accuracy_pct': 50.6478, 'median_time_s': 3.2009}, (32,): {'accuracy_pct': 39.5547, 'median_time_s': 3.0131}, (16,): {'accuracy_pct': 6.5587, 'median_time_s': 2.6951}}

# %%
print(progressive_trunc_knn)
# Out:
# {(64, 128, 4): {'accuracy_pct': 83.7247, 'median_time_s': 4.04}, (64, 128, 8): {'accuracy_pct': 85.2227, 'median_time_s': 4.07}, (64, 128, 16): {'accuracy_pct': 86.4372, 'median_time_s': 4.29}, (64, 128, 32): {'accuracy_pct': 87.247, 'median_time_s': 4.75}, (64, 128, 64): {'accuracy_pct': 87.8947, 'median_time_s': 5.475}, (64, 128, 128): {'accuracy_pct': 88.502, 'median_time_s': 6.51}, (64, 128, 256): {'accuracy_pct': 88.583, 'median_time_s': 8.105}, (64, 128, 512): {'accuracy_pct': 88.7449, 'median_time_s': 9.345}, (64, 128, 1024): {'accuracy_pct': 88.7449, 'median_time_s': 12.995}, (64, 256, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.04}, (64, 256, 8): {'accuracy_pct': 86.6397, 'median_time_s': 4.23}, (64, 256, 16): {'accuracy_pct': 88.4211, 'median_time_s': 4.51}, (64, 256, 32): {'accuracy_pct': 89.7571, 'median_time_s': 5.14}, (64, 256, 64): {'accuracy_pct': 90.5263, 'median_time_s': 6.19}, (64, 256, 128): {'accuracy_pct': 91.5385, 'median_time_s': 7.83}, (64, 256, 256): {'accuracy_pct': 91.9838, 'median_time_s': 10.655}, (64, 256, 512): {'accuracy_pct': 92.4696, 'median_time_s': 14.595}, (64, 256, 1024): {'accuracy_pct': 92.6721, 'median_time_s': 19.94}, (64, 512, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.11}, (64, 512, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.31}, (64, 512, 16): {'accuracy_pct': 88.7854, 'median_time_s': 4.72}, (64, 512, 32): {'accuracy_pct': 90.1215, 'median_time_s': 5.605}, (64, 512, 64): {'accuracy_pct': 91.0526, 'median_time_s': 7.05}, (64, 512, 128): {'accuracy_pct': 92.1457, 'median_time_s': 9.36}, (64, 512, 256): {'accuracy_pct': 92.7126, 'median_time_s': 13.21}, (64, 512, 512): {'accuracy_pct': 93.3198, 'median_time_s': 19.04}, (64, 512, 1024): {'accuracy_pct': 93.5628, 'median_time_s': 27.21}, (64, 1024, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.39}, (64, 1024, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.595}, (64, 1024, 16): {'accuracy_pct': 89.1498, 'median_time_s': 5.085}, (64, 1024, 32): {'accuracy_pct': 90.5263, 'median_time_s': 6.015}, (64, 1024, 64): {'accuracy_pct': 91.498, 'median_time_s': 7.82}, (64, 1024, 128): {'accuracy_pct': 92.6316, 'median_time_s': 10.495}, (64, 1024, 256): {'accuracy_pct': 93.2794, 'median_time_s': 13.915}, (64, 1024, 512): {'accuracy_pct': 93.9271, 'median_time_s': 20.76}, (64, 1024, 1024): {'accuracy_pct': 94.2105, 'median_time_s': 33.725}, (64, 2048, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.395}, (64, 2048, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.635}, (64, 2048, 16): {'accuracy_pct': 89.1498, 'median_time_s': 4.935}, (64, 2048, 32): {'accuracy_pct': 90.7287, 'median_time_s': 5.975}, (64, 2048, 64): {'accuracy_pct': 91.7409, 'median_time_s': 7.69}, (64, 2048, 128): {'accuracy_pct': 92.7935, 'median_time_s': 10.735}, (64, 2048, 256): {'accuracy_pct': 93.5223, 'median_time_s': 17.36}, (64, 2048, 512): {'accuracy_pct': 94.2105, 'median_time_s': 25.165}, (64, 2048, 1024): {'accuracy_pct': 94.6154, 'median_time_s': 42.135}, (64, 3584, 4): {'accuracy_pct': 84.8178, 'median_time_s': 4.66}, (64, 3584, 8): {'accuracy_pct': 86.8016, 'median_time_s': 4.92}, (64, 3584, 16): {'accuracy_pct': 89.1498, 'median_time_s': 5.41}, (64, 3584, 32): {'accuracy_pct': 90.7287, 'median_time_s': 6.49}, (64, 3584, 64): {'accuracy_pct': 91.7409, 'median_time_s': 8.69}, (64, 3584, 128): {'accuracy_pct': 92.834, 'median_time_s': 12.675}, (64, 3584, 256): {'accuracy_pct': 93.6032, 'median_time_s': 19.025}, (64, 3584, 512): {'accuracy_pct': 94.332, 'median_time_s': 31.17}, (64, 3584, 1024): {'accuracy_pct': 94.7368, 'median_time_s': 49.76}, (128, 256, 4): {'accuracy_pct': 92.2267, 'median_time_s': 5.815}, (128, 256, 8): {'accuracy_pct': 92.3077, 'median_time_s': 5.93}, (128, 256, 16): {'accuracy_pct': 92.5506, 'median_time_s': 6.225}, (128, 256, 32): {'accuracy_pct': 92.5911, 'median_time_s': 6.55}, (128, 256, 64): {'accuracy_pct': 92.6721, 'median_time_s': 7.525}, (128, 256, 128): {'accuracy_pct': 92.7935, 'median_time_s': 8.935}, (128, 256, ...

# %%
orig_dims, orig_times, orig_accs = [], [], []
for (dim,), stats in original_trunc_knn.items():
    orig_dims.append(dim)
    orig_times.append(stats["median_time_s"])
    orig_accs.append(stats["accuracy_pct"])

# sort by dimension so the line is monotonic
orig_sorted = sorted(zip(orig_dims, orig_times, orig_accs))
orig_dims, orig_times, orig_accs = map(list, zip(*orig_sorted))

# ---------- 2)  flatten the progressive results ----------
prog_sdim, prog_mdim, prog_k0  = [], [], []
prog_times, prog_accs          = [], []

for (s_dim, m_dim, k0), stats in progressive_trunc_knn.items():
    prog_sdim.append(s_dim)
    prog_mdim.append(m_dim)
    prog_k0.append(k0)
    prog_times.append(stats["median_time_s"])
    prog_accs.append(stats["accuracy_pct"])

# ---------- 3)  build traces ----------
trace_baseline = go.Scatter(
    x = orig_times,
    y = orig_accs,
    mode   = "lines+markers",
    line   = dict(color="royalblue"),
    marker = dict(symbol="circle", size=9),
    name   = "Truncate‑KNN baseline",
    text   = [f"Dim: {d}<br>Acc: {acc:.4f}%<br>Time: {t:.4f}s"
              for d, acc, t in zip(orig_dims, orig_accs, orig_times)],
    hoverinfo = "text"
)

trace_prog = go.Scatter(
    x = prog_times,
    y = prog_accs,
    mode   = "markers",
    marker = dict(color="crimson", symbol="square", size=8, opacity=0.85),
    name   = "Progressive KNN",
    text   = [
        (f"Start dim: {s}<br>End dim: {m}<br>Start k: {k0}"
         f"<br>Acc: {acc:.4f}%<br>Time: {t:.4f}s")
        for s, m, k0, acc, t in zip(
            prog_sdim, prog_mdim, prog_k0, prog_accs, prog_times)
    ],
    hoverinfo = "text"
)

# ---------- 4)  figure ----------
layout = go.Layout(
    title = "Accuracy vs Search Time  (Truncate‑KNN baseline  vs  Progressive KNN)",
    xaxis = dict(title="Median search time per query (s)"),
    yaxis = dict(title="Top‑1 accuracy (%)", range=[min(min(orig_accs),min(prog_accs))-1, 100]),
    height = 700,
    template = "plotly_white",
    hovermode = "closest"
)

fig = go.Figure(data=[trace_baseline, trace_prog], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7cfc5624-681d-48b1-b719-fb6467468598" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cfc5624-681d-48b1-b719-fb6467468598")) {                    Plotly.newPlot(                        "7cfc5624-681d-48b1-b719-fb6467468598",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN baseline","text":["Dim: 16\u003cbr\u003eAcc: 6.5587%\u003cbr\u003eTime: 2.6951s","Dim: 32\u003cbr\u003eAcc: 39.5547%\u003cbr\u003eTime: 3.0131s","Dim: 40\u003cbr\u003eAcc: 50.6478%\u003cbr\u003eTime: 3.2009s","Dim: 48\u003cbr\u003eAcc: 62.7126%\u003cbr\u003eTime: 3.4405s","Dim: 56\u003cbr\u003eAcc: 71.7814%\u003cbr\u003eTime: 3.6586s","Dim: 64\u003cbr\u003eAcc: 78.4211%\u003cbr\u003eTime: 3.8344s","Dim: 72\u003cbr\u003eAcc: 76.8826%\u003cbr\u003eTime: 4.1680s","Dim: 80\u003cbr\u003eAcc: 80.5263%\u003cbr\u003eTime: 4.3103s","Dim: 88\u003cbr\u003eAcc: 83.1579%\u003cbr\u003eTime: 4.5491s","Dim: 96\u003cbr\u003eAcc: 84.9798%\u003cbr\u003eTime: 4.8325s","Dim: 104\u003cbr\u003eAcc: 86.5587%\u003cbr\u003eTime: 5.0233s","Dim: 112\u003cbr\u003eAcc: 87.8543%\u003cbr\u003eTime: 5.1778s","Dim: 120\u003cbr\u003eAcc: 88.3806%\u003cbr\u003eTime: 5.4877s","Dim: 128\u003cbr\u003eAcc: 88.7854%\u003cbr\u003eTime: 5.7095s","Dim: 136\u003cbr\u003eAcc: 89.5547%\u003cbr\u003eTime: 5.8922s","Dim: 144\u003cbr\u003eAcc: 89.6356%\u003cbr\u003eTime: 6.1132s","Dim: 152\u003cbr\u003eAcc: 90.0810%\u003cbr\u003eTime: 6.3164s","Dim: 160\u003cbr\u003eAcc: 90.6073%\u003cbr\u003eTime: 6.6011s","Dim: 168\u003cbr\u003eAcc: 90.8502%\u003cbr\u003eTime: 6.8448s","Dim: 176\u003cbr\u003eAcc: 91.0526%\u003cbr\u003eTime: 6.9511s","Dim: 184\u003cbr\u003eAcc: 91.3765%\u003cbr\u003eTime: 7.2308s","Dim: 192\u003cbr\u003eAcc: 91.5789%\u003cbr\u003eTime: 7.4458s","Dim: 200\u003cbr\u003eAcc: 91.7409%\u003cbr\u003eTime: 7.6921s","Dim: 208\u003cbr\u003eAcc: 91.8623%\u003cbr\u003eTime: 7.9734s","Dim: 216\u003cbr\u003eAcc: 91.9838%\u003cbr\u003eTime: 8.1986s","Dim: 224\u003cbr\u003eAcc: 92.2267%\u003cbr\u003eTime: 8.5350s","Dim: 232\u003cbr\u003eAcc: 92.4291%\u003cbr\u003eTime: 8.5756s","Dim: 240\u003cbr\u003eAcc: 92.5911%\u003cbr\u003eTime: 8.9192s","Dim: 248\u003cbr\u003eAcc: 92.8745%\u003cbr\u003eTime: 9.1377s","Dim: 256\u003cbr\u003eAcc: 92.7935%\u003cbr\u003eTime: 9.3839s","Dim: 264\u003cbr\u003eAcc: 93.0364%\u003cbr\u003eTime: 9.5435s","Dim: 272\u003cbr\u003eAcc: 92.9555%\u003cbr\u003eTime: 9.7931s","Dim: 280\u003cbr\u003eAcc: 93.1579%\u003cbr\u003eTime: 9.9632s","Dim: 288\u003cbr\u003eAcc: 93.0769%\u003cbr\u003eTime: 10.1855s","Dim: 296\u003cbr\u003eAcc: 92.5506%\u003cbr\u003eTime: 10.4184s","Dim: 304\u003cbr\u003eAcc: 92.3887%\u003cbr\u003eTime: 10.5377s","Dim: 312\u003cbr\u003eAcc: 92.5911%\u003cbr\u003eTime: 10.7416s","Dim: 320\u003cbr\u003eAcc: 92.7126%\u003cbr\u003eTime: 10.8814s","Dim: 328\u003cbr\u003eAcc: 92.8745%\u003cbr\u003eTime: 11.1568s","Dim: 336\u003cbr\u003eAcc: 92.8745%\u003cbr\u003eTime: 11.3801s","Dim: 344\u003cbr\u003eAcc: 92.9555%\u003cbr\u003eTime: 11.5171s","Dim: 352\u003cbr\u003eAcc: 93.1579%\u003cbr\u003eTime: 11.7205s","Dim: 360\u003cbr\u003eAcc: 93.2389%\u003cbr\u003eTime: 11.9688s","Dim: 368\u003cbr\u003eAcc: 93.2794%\u003cbr\u003eTime: 12.0985s","Dim: 376\u003cbr\u003eAcc: 93.2794%\u003cbr\u003eTime: 12.4153s","Dim: 384\u003cbr\u003eAcc: 93.4008%\u003cbr\u003eTime: 12.8413s","Dim: 392\u003cbr\u003eAcc: 93.5223%\u003cbr\u003eTime: 13.0533s","Dim: 400\u003cbr\u003eAcc: 93.6032%\u003cbr\u003eTime: 13.3905s","Dim: 408\u003cbr\u003eAcc: 93.5628%\u003cbr\u003eTime: 13.5728s","Dim: 416\u003cbr\u003eAcc: 93.6032%\u003cbr\u003eTime: 13.6727s","Dim: 424\u003cbr\u003eAcc ...

# %% [markdown]
# ## In detailed

# %%
prog_marker_style = dict(symbol="square", size=8, opacity=0.85, color="crimson")
baseline_style    = dict(symbol="circle", size=9, color="royalblue")


# baseline vectors
orig_dims, orig_times, orig_accs = [], [], []
for (dim,), stats in original_trunc_knn.items():
    orig_dims.append(dim)
    orig_times.append(stats["median_time_s"])
    orig_accs.append(stats["accuracy_pct"])
orig_sorted = sorted(zip(orig_dims, orig_times, orig_accs))
orig_dims, orig_times, orig_accs = map(list, zip(*orig_sorted))

baseline_trace = go.Scatter(
    x     = orig_times,
    y     = orig_accs,
    mode  = "lines+markers",
    marker= baseline_style,
    line  = dict(color=baseline_style["color"]),
    name  = "Truncate‑KNN baseline",
    hoverinfo = "text",
    text  = [f"Dim {d}<br>Acc {a:.4f}%<br>{t:.4f}s"
             for d, a, t in zip(orig_dims, orig_accs, orig_times)]
)

# helper that makes one figure
def make_figure(subset_keys, title_suffix):
    prog_times, prog_accs, prog_hover = [], [], []
    for key in subset_keys:
        s_dim, m_dim, k0 = key
        stats  = progressive_trunc_knn[key]
        prog_times.append(stats["median_time_s"])
        prog_accs.append(stats["accuracy_pct"])
        prog_hover.append(
            f"Start { s_dim } → End { m_dim }<br>k₀={k0}"
            f"<br>Acc {stats['accuracy_pct']:.4f}%"
            f"<br>{stats['median_time_s']:.4f}s"
        )

    prog_trace = go.Scatter(
        x = prog_times, y = prog_accs,
        mode   = "markers",
        marker = prog_marker_style,
        name   = "Progressive KNN",
        text   = prog_hover, hoverinfo="text"
    )

    layout = go.Layout(
        title = f"Accuracy vs Time {title_suffix}",
        xaxis = dict(title="Median search time (s)"),
        yaxis = dict(title="Top‑1 accuracy (%)",
                     range=[min(min(orig_accs),min(prog_accs))-1, 100]),
        template="plotly_white", height=650, hovermode="closest"
    )
    fig = go.Figure(data=[baseline_trace, prog_trace], layout=layout)
    fig.show()

# %% [markdown]
# ### By Dim range

# %%
# build unique range list
ranges = sorted({(s_dim, m_dim) for (s_dim, m_dim, _) in progressive_trunc_knn})
for s_dim, m_dim in ranges:
    keys = [k for k in progressive_trunc_knn if k[0]==s_dim and k[1]==m_dim]
    make_figure(keys, f"(range { s_dim } → { m_dim })")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0007af17-46a3-42af-ab20-6d57047e3860" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0007af17-46a3-42af-ab20-6d57047e3860")) {                    Plotly.newPlot(                        "0007af17-46a3-42af-ab20-6d57047e3860",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6da4e94f-8119-4208-a1f6-a227ff26b70c" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6da4e94f-8119-4208-a1f6-a227ff26b70c")) {                    Plotly.newPlot(                        "6da4e94f-8119-4208-a1f6-a227ff26b70c",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="124e91f9-2d72-4c4b-b743-1236fbd3a093" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("124e91f9-2d72-4c4b-b743-1236fbd3a093")) {                    Plotly.newPlot(                        "124e91f9-2d72-4c4b-b743-1236fbd3a093",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7213fdab-748a-4077-95d0-fe8b21cc021f" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7213fdab-748a-4077-95d0-fe8b21cc021f")) {                    Plotly.newPlot(                        "7213fdab-748a-4077-95d0-fe8b21cc021f",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="12a4f7cb-7592-4ad8-8e4b-722e963ece8c" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12a4f7cb-7592-4ad8-8e4b-722e963ece8c")) {                    Plotly.newPlot(                        "12a4f7cb-7592-4ad8-8e4b-722e963ece8c",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dd2d966e-acc1-4c88-b52a-6d3b613d49bc" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd2d966e-acc1-4c88-b52a-6d3b613d49bc")) {                    Plotly.newPlot(                        "dd2d966e-acc1-4c88-b52a-6d3b613d49bc",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4f3e1074-1f94-4c53-9c6c-9a95accd352b" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f3e1074-1f94-4c53-9c6c-9a95accd352b")) {                    Plotly.newPlot(                        "4f3e1074-1f94-4c53-9c6c-9a95accd352b",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c04c1226-45c2-49ff-b9ac-9d258881656e" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c04c1226-45c2-49ff-b9ac-9d258881656e")) {                    Plotly.newPlot(                        "c04c1226-45c2-49ff-b9ac-9d258881656e",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="39ac2b1e-a7ca-490d-9de1-401a77d2f25b" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39ac2b1e-a7ca-490d-9de1-401a77d2f25b")) {                    Plotly.newPlot(                        "39ac2b1e-a7ca-490d-9de1-401a77d2f25b",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2e481243-0f03-46e6-8ed3-37e6c3bf53f0" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e481243-0f03-46e6-8ed3-37e6c3bf53f0")) {                    Plotly.newPlot(                        "2e481243-0f03-46e6-8ed3-37e6c3bf53f0",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="73fa4445-fed0-44d1-8ecf-b1520ecd053f" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73fa4445-fed0-44d1-8ecf-b1520ecd053f")) {                    Plotly.newPlot(                        "73fa4445-fed0-44d1-8ecf-b1520ecd053f",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="31c77d14-2d89-4336-826f-47d3ac5699c0" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31c77d14-2d89-4336-826f-47d3ac5699c0")) {                    Plotly.newPlot(                        "31c77d14-2d89-4336-826f-47d3ac5699c0",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a4a2cabc-b4e3-4fc1-a39b-69db3be9dc36" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4a2cabc-b4e3-4fc1-a39b-69db3be9dc36")) {                    Plotly.newPlot(                        "a4a2cabc-b4e3-4fc1-a39b-69db3be9dc36",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...

# %% [markdown]
# ### By start_k

# %%
k_vals = sorted({k0 for *_, k0 in progressive_trunc_knn})
for k0 in k_vals:
    keys = [k for k in progressive_trunc_knn if k[2]==k0]
    make_figure(keys, f"(start‑k = {k0})")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7e3954a8-0053-41a1-8934-8744120bd438" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e3954a8-0053-41a1-8934-8744120bd438")) {                    Plotly.newPlot(                        "7e3954a8-0053-41a1-8934-8744120bd438",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c1ae8c9-6e7e-4d92-a2a4-1081ea4d6c1c" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c1ae8c9-6e7e-4d92-a2a4-1081ea4d6c1c")) {                    Plotly.newPlot(                        "5c1ae8c9-6e7e-4d92-a2a4-1081ea4d6c1c",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1141a077-d2d4-409d-a361-c3ea1e2d84eb" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1141a077-d2d4-409d-a361-c3ea1e2d84eb")) {                    Plotly.newPlot(                        "1141a077-d2d4-409d-a361-c3ea1e2d84eb",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b35fa585-6607-42ca-9ba9-33651dcf6f66" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b35fa585-6607-42ca-9ba9-33651dcf6f66")) {                    Plotly.newPlot(                        "b35fa585-6607-42ca-9ba9-33651dcf6f66",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="97518851-bd0d-4ca3-b653-e1108eda2200" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97518851-bd0d-4ca3-b653-e1108eda2200")) {                    Plotly.newPlot(                        "97518851-bd0d-4ca3-b653-e1108eda2200",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fbcbf109-011f-4c54-b9a2-4cc62ed6d656" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fbcbf109-011f-4c54-b9a2-4cc62ed6d656")) {                    Plotly.newPlot(                        "fbcbf109-011f-4c54-b9a2-4cc62ed6d656",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7360239b-cf1a-4e59-b792-1105f9b4f4e7" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7360239b-cf1a-4e59-b792-1105f9b4f4e7")) {                    Plotly.newPlot(                        "7360239b-cf1a-4e59-b792-1105f9b4f4e7",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="482df4f7-86db-48b6-8e38-1ee3a1c90ef5" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("482df4f7-86db-48b6-8e38-1ee3a1c90ef5")) {                    Plotly.newPlot(                        "482df4f7-86db-48b6-8e38-1ee3a1c90ef5",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3647d64f-2ab2-4bad-93b5-7431cde34350" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3647d64f-2ab2-4bad-93b5-7431cde34350")) {                    Plotly.newPlot(                        "3647d64f-2ab2-4bad-93b5-7431cde34350",                        [{"hoverinfo":"text","line":{"color":"royalblue"},"marker":{"color":"royalblue","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Truncate\u2011KNN\u00a0baseline","text":["Dim\u00a016\u003cbr\u003eAcc\u202f6.5587%\u003cbr\u003e2.6951s","Dim\u00a032\u003cbr\u003eAcc\u202f39.5547%\u003cbr\u003e3.0131s","Dim\u00a040\u003cbr\u003eAcc\u202f50.6478%\u003cbr\u003e3.2009s","Dim\u00a048\u003cbr\u003eAcc\u202f62.7126%\u003cbr\u003e3.4405s","Dim\u00a056\u003cbr\u003eAcc\u202f71.7814%\u003cbr\u003e3.6586s","Dim\u00a064\u003cbr\u003eAcc\u202f78.4211%\u003cbr\u003e3.8344s","Dim\u00a072\u003cbr\u003eAcc\u202f76.8826%\u003cbr\u003e4.1680s","Dim\u00a080\u003cbr\u003eAcc\u202f80.5263%\u003cbr\u003e4.3103s","Dim\u00a088\u003cbr\u003eAcc\u202f83.1579%\u003cbr\u003e4.5491s","Dim\u00a096\u003cbr\u003eAcc\u202f84.9798%\u003cbr\u003e4.8325s","Dim\u00a0104\u003cbr\u003eAcc\u202f86.5587%\u003cbr\u003e5.0233s","Dim\u00a0112\u003cbr\u003eAcc\u202f87.8543%\u003cbr\u003e5.1778s","Dim\u00a0120\u003cbr\u003eAcc\u202f88.3806%\u003cbr\u003e5.4877s","Dim\u00a0128\u003cbr\u003eAcc\u202f88.7854%\u003cbr\u003e5.7095s","Dim\u00a0136\u003cbr\u003eAcc\u202f89.5547%\u003cbr\u003e5.8922s","Dim\u00a0144\u003cbr\u003eAcc\u202f89.6356%\u003cbr\u003e6.1132s","Dim\u00a0152\u003cbr\u003eAcc\u202f90.0810%\u003cbr\u003e6.3164s","Dim\u00a0160\u003cbr\u003eAcc\u202f90.6073%\u003cbr\u003e6.6011s","Dim\u00a0168\u003cbr\u003eAcc\u202f90.8502%\u003cbr\u003e6.8448s","Dim\u00a0176\u003cbr\u003eAcc\u202f91.0526%\u003cbr\u003e6.9511s","Dim\u00a0184\u003cbr\u003eAcc\u202f91.3765%\u003cbr\u003e7.2308s","Dim\u00a0192\u003cbr\u003eAcc\u202f91.5789%\u003cbr\u003e7.4458s","Dim\u00a0200\u003cbr\u003eAcc\u202f91.7409%\u003cbr\u003e7.6921s","Dim\u00a0208\u003cbr\u003eAcc\u202f91.8623%\u003cbr\u003e7.9734s","Dim\u00a0216\u003cbr\u003eAcc\u202f91.9838%\u003cbr\u003e8.1986s","Dim\u00a0224\u003cbr\u003eAcc\u202f92.2267%\u003cbr\u003e8.5350s","Dim\u00a0232\u003cbr\u003eAcc\u202f92.4291%\u003cbr\u003e8.5756s","Dim\u00a0240\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e8.9192s","Dim\u00a0248\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e9.1377s","Dim\u00a0256\u003cbr\u003eAcc\u202f92.7935%\u003cbr\u003e9.3839s","Dim\u00a0264\u003cbr\u003eAcc\u202f93.0364%\u003cbr\u003e9.5435s","Dim\u00a0272\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e9.7931s","Dim\u00a0280\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e9.9632s","Dim\u00a0288\u003cbr\u003eAcc\u202f93.0769%\u003cbr\u003e10.1855s","Dim\u00a0296\u003cbr\u003eAcc\u202f92.5506%\u003cbr\u003e10.4184s","Dim\u00a0304\u003cbr\u003eAcc\u202f92.3887%\u003cbr\u003e10.5377s","Dim\u00a0312\u003cbr\u003eAcc\u202f92.5911%\u003cbr\u003e10.7416s","Dim\u00a0320\u003cbr\u003eAcc\u202f92.7126%\u003cbr\u003e10.8814s","Dim\u00a0328\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.1568s","Dim\u00a0336\u003cbr\u003eAcc\u202f92.8745%\u003cbr\u003e11.3801s","Dim\u00a0344\u003cbr\u003eAcc\u202f92.9555%\u003cbr\u003e11.5171s","Dim\u00a0352\u003cbr\u003eAcc\u202f93.1579%\u003cbr\u003e11.7205s","Dim\u00a0360\u003cbr\u003eAcc\u202f93.2389%\u003cbr\u003e11.9688s","Dim\u00a0368\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.0985s","Dim\u00a0376\u003cbr\u003eAcc\u202f93.2794%\u003cbr\u003e12.4153s","Dim\u00a0384\u003cbr\u003eAcc\u202f93.4008%\u003cbr\u003e12.8413s","Dim\u00a0392\u003cbr\u003eAcc\u202f93.5223%\u003cbr\u003e13.0533s","Dim\u00a0400\u003cbr\u003eAcc\u202f93.6032%\u003cbr\u003e13.3905s","Dim\u00a0408\u003cbr\u003eAcc\u202f9 ...

# %% [markdown]
# # Print

# %%
for k, v in original_trunc_knn.items():
    print(f"{k} | {v['accuracy_pct']:7.4f}%  | {v['median_time_s']:8.4f}s")
# Out:
# (3584,) | 95.0202%  |  99.3581s
# (3072,) | 94.9798%  |  87.5013s
# (2048,) | 94.8178%  |  57.4883s
# (1024,) | 94.4939%  |  29.6964s
# (512,) | 93.8057%  |  16.4421s
# (504,) | 93.8866%  |  15.7597s
# (496,) | 93.8057%  |  15.6233s
# (488,) | 93.7652%  |  15.3404s
# (480,) | 93.7247%  |  15.0536s
# (472,) | 93.7652%  |  14.7977s
# (464,) | 93.8057%  |  14.7158s
# (456,) | 93.7652%  |  14.5692s
# (448,) | 93.6842%  |  14.3969s
# (440,) | 93.5628%  |  14.2381s
# (432,) | 93.5223%  |  13.9428s
# (424,) | 93.6032%  |  14.0046s
# (416,) | 93.6032%  |  13.6727s
# (408,) | 93.5628%  |  13.5728s
# (400,) | 93.6032%  |  13.3905s
# (392,) | 93.5223%  |  13.0533s
# (384,) | 93.4008%  |  12.8413s
# (376,) | 93.2794%  |  12.4153s
# (368,) | 93.2794%  |  12.0985s
# (360,) | 93.2389%  |  11.9688s
# (352,) | 93.1579%  |  11.7205s
# (344,) | 92.9555%  |  11.5171s
# (336,) | 92.8745%  |  11.3801s
# (328,) | 92.8745%  |  11.1568s
# (320,) | 92.7126%  |  10.8814s
# (312,) | 92.5911%  |  10.7416s
# (304,) | 92.3887%  |  10.5377s
# (296,) | 92.5506%  |  10.4184s
# (288,) | 93.0769%  |  10.1855s
# (280,) | 93.1579%  |   9.9632s
# (272,) | 92.9555%  |   9.7931s
# (264,) | 93.0364%  |   9.5435s
# (256,) | 92.7935%  |   9.3839s
# (248,) | 92.8745%  |   9.1377s
# (240,) | 92.5911%  |   8.9192s
# (232,) | 92.4291%  |   8.5756s
# (224,) | 92.2267%  |   8.5350s
# (216,) | 91.9838%  |   8.1986s
# (208,) | 91.8623%  |   7.9734s
# (200,) | 91.7409%  |   7.6921s
# (192,) | 91.5789%  |   7.4458s
# (184,) | 91.3765%  |   7.2308s
# (176,) | 91.0526%  |   6.9511s
# (168,) | 90.8502%  |   6.8448s
# (160,) | 90.6073%  |   6.6011s
# (152,) | 90.0810%  |   6.3164s
# (144,) | 89.6356%  |   6.1132s
# (136,) | 89.5547%  |   5.8922s
# (128,) | 88.7854%  |   5.7095s
# (120,) | 88.3806%  |   5.4877s
# (112,) | 87.8543%  |   5.1778s
# (104,) | 86.5587%  |   5.0233s
# (96,) | 84.9798%  |   4.8325s
# (88,) | 83.1579%  |   4.5491s
# (80,) | 80.5263%  |   4.3103s
# (72,) | 76.8826%  |   4.1680s
# (64,) | 78.4211%  |   3.8344s
# (56,) | 71.7814%  |   3.6586s
# (48,) | 62.7126%  |   3.4405s
# (40,) | 50.6478%  |   3.2009s
# (32,) | 39.5547%  |   3.0131s
# (16,) |  6.5587%  |   2.6951s

# %%
for k, v in progressive_trunc_knn.items():
    print(f"{k} | {v['accuracy_pct']:7.4f}%  | {v['median_time_s']:8.4f}s")
# Out:
# (64, 128, 4) | 83.7247%  |   4.0400s
# (64, 128, 8) | 85.2227%  |   4.0700s
# (64, 128, 16) | 86.4372%  |   4.2900s
# (64, 128, 32) | 87.2470%  |   4.7500s
# (64, 128, 64) | 87.8947%  |   5.4750s
# (64, 128, 128) | 88.5020%  |   6.5100s
# (64, 128, 256) | 88.5830%  |   8.1050s
# (64, 128, 512) | 88.7449%  |   9.3450s
# (64, 128, 1024) | 88.7449%  |  12.9950s
# (64, 256, 4) | 84.8178%  |   4.0400s
# (64, 256, 8) | 86.6397%  |   4.2300s
# (64, 256, 16) | 88.4211%  |   4.5100s
# (64, 256, 32) | 89.7571%  |   5.1400s
# (64, 256, 64) | 90.5263%  |   6.1900s
# (64, 256, 128) | 91.5385%  |   7.8300s
# (64, 256, 256) | 91.9838%  |  10.6550s
# (64, 256, 512) | 92.4696%  |  14.5950s
# (64, 256, 1024) | 92.6721%  |  19.9400s
# (64, 512, 4) | 84.8178%  |   4.1100s
# (64, 512, 8) | 86.8016%  |   4.3100s
# (64, 512, 16) | 88.7854%  |   4.7200s
# (64, 512, 32) | 90.1215%  |   5.6050s
# (64, 512, 64) | 91.0526%  |   7.0500s
# (64, 512, 128) | 92.1457%  |   9.3600s
# (64, 512, 256) | 92.7126%  |  13.2100s
# (64, 512, 512) | 93.3198%  |  19.0400s
# (64, 512, 1024) | 93.5628%  |  27.2100s
# (64, 1024, 4) | 84.8178%  |   4.3900s
# (64, 1024, 8) | 86.8016%  |   4.5950s
# (64, 1024, 16) | 89.1498%  |   5.0850s
# (64, 1024, 32) | 90.5263%  |   6.0150s
# (64, 1024, 64) | 91.4980%  |   7.8200s
# (64, 1024, 128) | 92.6316%  |  10.4950s
# (64, 1024, 256) | 93.2794%  |  13.9150s
# (64, 1024, 512) | 93.9271%  |  20.7600s
# (64, 1024, 1024) | 94.2105%  |  33.7250s
# (64, 2048, 4) | 84.8178%  |   4.3950s
# (64, 2048, 8) | 86.8016%  |   4.6350s
# (64, 2048, 16) | 89.1498%  |   4.9350s
# (64, 2048, 32) | 90.7287%  |   5.9750s
# (64, 2048, 64) | 91.7409%  |   7.6900s
# (64, 2048, 128) | 92.7935%  |  10.7350s
# (64, 2048, 256) | 93.5223%  |  17.3600s
# (64, 2048, 512) | 94.2105%  |  25.1650s
# (64, 2048, 1024) | 94.6154%  |  42.1350s
# (64, 3584, 4) | 84.8178%  |   4.6600s
# (64, 3584, 8) | 86.8016%  |   4.9200s
# (64, 3584, 16) | 89.1498%  |   5.4100s
# (64, 3584, 32) | 90.7287%  |   6.4900s
# (64, 3584, 64) | 91.7409%  |   8.6900s
# (64, 3584, 128) | 92.8340%  |  12.6750s
# (64, 3584, 256) | 93.6032%  |  19.0250s
# (64, 3584, 512) | 94.3320%  |  31.1700s
# (64, 3584, 1024) | 94.7368%  |  49.7600s
# (128, 256, 4) | 92.2267%  |   5.8150s
# (128, 256, 8) | 92.3077%  |   5.9300s
# (128, 256, 16) | 92.5506%  |   6.2250s
# (128, 256, 32) | 92.5911%  |   6.5500s
# (128, 256, 64) | 92.6721%  |   7.5250s
# (128, 256, 128) | 92.7935%  |   8.9350s
# (128, 256, 256) | 92.7935%  |  10.8250s
# (128, 256, 512) | 92.7935%  |  13.4050s
# (128, 256, 1024) | 92.7935%  |  16.5750s
# (128, 512, 4) | 92.3077%  |   6.0600s
# (128, 512, 8) | 92.7126%  |   6.2600s
# (128, 512, 16) | 93.1174%  |   6.7250s
# (128, 512, 32) | 93.4008%  |   7.5500s
# (128, 512, 64) | 93.4818%  |   9.0900s
# (128, 512, 128) | 93.6437%  |  11.6150s
# (128, 512, 256) | 93.7652%  |  15.7900s
# (128, 512, 512) | 93.7652%  |  21.7100s
# (128, 512, 1024) | 93.7652%  |  28.3500s
# (128, 1024, 4) | 92.3077%  |   6.1500s
# (128, 1024, 8) | 93.2389%  |   6.4400s
# (128, 1024, 16) | 93.6437%  |   7.1250s
# (128, 1024, 32) | 93.9676%  |   8.3850s
# (128, 1024, 64) | 94.0486%  |  10.4350s
# (128, 1024, 128) | 94.2915%  |  14.2150s
# (128, 1024, 256) | 94.4130%  |  20.3950s
# (128, 1024, 512) | 94.4130%  |  29.4300s
# (128, 1024, 1024) | 94.4534%  |  41.8250s
# (128, 2048, 4) | 92.3077%  |   6.2500s
# (128, 2048, 8) | 93.2389%  |   6.5600s
# (128, 2048, 16) | 93.8866%  |   7.3900s
# (128, 2048, 32) | 94.2510%  |   8.8750s
# (128, 2048, 64) | 94.4130%  |  11.5150s
# (128, 2048, 128) | 94.6559%  |  16.4250s
# (128, 2048, 256) | 94.8178%  |  24.3500s
# (128, 2048, 512) | 94.8178%  |  35.1900s
# (128, 2048, 1024) | 94.7773%  |  56.3350s
# (128, 3584, 4) | 92.3077%  |   6.6100s
# (128, 3584, 8) | 93.2389%  |   6.8650s
# (128, 3584, 16) | 93.8866%  |   7.4500s
# (128, 3584, 32) | 94.2915%  |   9.0550s
# (128, 3584, 64) | 94.4939%  |  12.1750s
# (128, 3584, 128) | 94.7368%  |  17.6500s
# (128, 3584, 256) | 94.8988%  |  26.7950s
# (128, 3584, 512) | 94.9393%  |  42.8600s
# (128, 3584, 1024) | 94.9798%  |  66.9800s
# (256, 512, 4) | 93.4818%  |   9.3250s
# (256, 512, 8) | 93.6437%  |   9.5300s
# (256, 512, 16) | 93.7247%  |  10.0050s
# (256, 512, 32) | 93.7652%  |  10.7150s
# (256, 512, 64) | 93.8057%  |  11.9800s
# (256, 512, 128) | 93.8057%  |  14.4750s
# (256, 512, 256) | 93.8057%  |  17.7500s
# (256, 512, 512) | 93.8057%  |  23.0250s
# (256, 512, 1024) | 93.8057%  |  27.9550s
# (256, 1024, 4) | 94.1296%  |   9.8600s
# (256, 1024, 8) | 94.3320%  |  10.3200s
# (256, 1024, 16) | 94.3320%  |  11.0250s
# (256, 1024, 32) | 94.4130%  |  12.5100s
# (256, 1024, 64) | 94.4534%  |  15.1350s
# (256, 1024, 128) | 94.4534%  |  19.6950s
# (256, 1024, 256) | 94.4534%  |  27.0550s
# (256, 1024, 512) | 94.4939%  |  36.9250s
# (256, 1024, 1024) | 94.4939%  |  48.8900s
# (256, 2048, 4) | 94.1296%  |   9.9650s
# (256, 2048, 8) | 94.7368%  |  10.4800s
# (256, 2048, 16) | 94.7368%  |  11.5950s
# (256, 2048, 32) | 94.8178%  |  13.7850s
# (256, 2048, 64) | 94.8583%  |  17.6700s
# (256, 2048, 128) | 94.8178%  |  24.3400s
# (256, 2048, 256) | 94.8178%  |  35.7850s
# (256, 2048, 512) | 94.8178%  |  52.4400s
# (256, 2048, 1024) | 94.8178%  |  75.4400s
# (256, 3584, 4) | 94.1296%  |  10.1850s
# (256, 3584, 8) | 94.7368%  |  10.7100s
# (256, 3584, 16) | 94.8178%  |  12.1650s
# (256, 3584, 32) | 94.9393%  |  14.6300s
# (256, 3584, 64) | 94.9798%  |  19.1550s
# (256, 3584, 128) | 94.9798%  |  27.5250s
# (256, 3584, 256) | 94.9798%  |  41.9650s
# (256, 3584, 512) | 95.0202%  |  65.3250s
# (256, 3584, 1024) | 95.0202%  |  99.2700s
# (512, 1024, 4) | 94.4939%  |  17.2400s
# (512, 1024, 8) | 94.4939%  |  17.6500s
# (512, 1024, 16) | 94.4939%  |  18.6300s
# (512, 1024, 32) | 94.4939%  |  19.4250s
# (512, 1024, 64) | 94.4939%  |  21.7550s
# (512, 1024, 128) | 94.4939%  |  25.7100s
# (512, 1024, 256) | 94.4939%  |  31.5300s
# (512, 1024, 512) | 94.4939%  |  39.3500s
# (512, 1024, 1024) | 94.4939%  |  47.1800s
# (512, 2048, 4) | 94.8583%  |  17.6950s
# (512, 2048, 8) | 94.8583%  |  18.3000s
# (512, 2048, 16) | 94.8988%  |  19.8100s
# (512, 2048, 32) | 94.8583%  |  22.2450s
# (512, 2048, 64) | 94.8583%  |  26.9700s
# (512, 2048, 128) | 94.8583%  |  34.8550s
# (512, 2048, 256) | 94.8178%  |  47.0400s
# (512, 2048, 512) | 94.8178%  |  65.8800s
# (512, 2048, 1024) | 94.8178%  |  92.9300s
# (512, 3584, 4) | 94.8583%  |  18.0950s
# (512, 3584, 8) | 94.9393%  |  18.8050s
# (512, 3584, 16) | 95.0202%  |  20.6300s
# (512, 3584, 32) | 95.0202%  |  24.1600s
# (512, 3584, 64) | 95.0202%  |  30.6300s
# (512, 3584, 128) | 95.0202%  |  42.4900s
# (512, 3584, 256) | 95.0202%  |  62.0700s
# (512, 3584, 512) | 95.0202%  |  95.4050s
# (512, 3584, 1024) | 95.0202%  | 135.4550s
# (1024, 2048, 4) | 94.8583%  |  31.2200s
# (1024, 2048, 8) | 94.8583%  |  31.9000s
# (1024, 2048, 16) | 94.8583%  |  32.5550s
# (1024, 2048, 32) | 94.8583%  |  35.1300s
# (1024, 2048, 64) | 94.8583%  |  39.3450s
# (1024, 2048, 128) | 94.8178%  |  46.6600s
# (1024, 2048, 256) | 94.8178%  |  57.8500s
# (1024, 2048, 512) | 94.8178%  |  71.3000s
# (1024, 2048, 1024) | 94.8178%  |  84.7350s
# (1024, 3584, 4) | 94.9798%  |  31.4450s
# (1024, 3584, 8) | 95.0202%  |  32.3550s
# (1024, 3584, 16) | 95.0202%  |  35.2950s
# (1024, 3584, 32) | 95.0202%  |  40.0800s
# (1024, 3584, 64) | 95.0202%  |  48.2700s
# (1024, 3584, 128) | 95.0202%  |  63.3150s
# (1024, 3584, 256) | 95.0202%  |  84.5450s
# (1024, 3584, 512) | 95.0202%  | 115.0250s
# (1024, 3584, 1024) | 95.0202%  | 150.8050s
# (2048, 3584, 4) | 95.0202%  |  58.8750s
# (2048, 3584, 8) | 95.0202%  |  59.8500s
# (2048, 3584, 16) | 95.0202%  |  62.0150s
# (2048, 3584, 32) | 95.0202%  |  66.1350s
# (2048, 3584, 64) | 95.0202%  |  73.2850s
# (2048, 3584, 128) | 95.0202%  |  86.0850s
# (2048, 3584, 256) | 95.0202%  | 104.9600s
# (2048, 3584, 512) | 95.0202%  | 133.5700s
# (2048, 3584, 1024) | 95.0202%  | 155.9250s

# %%
print(f"{'K':<20} {'Accuracy %':<10} {'Median Time (s)':<15}")

for k, v in original_trunc_knn.items():
    print(f"{str(k):<20} {v['accuracy_pct']:.4f}%    {v['median_time_s']:8.4f}s")
# Out:
# K                    Accuracy % Median Time (s)
# (3584,)              95.0202%     99.3581s
# (3072,)              94.9798%     87.5013s
# (2048,)              94.8178%     57.4883s
# (1024,)              94.4939%     29.6964s
# (512,)               93.8057%     16.4421s
# (504,)               93.8866%     15.7597s
# (496,)               93.8057%     15.6233s
# (488,)               93.7652%     15.3404s
# (480,)               93.7247%     15.0536s
# (472,)               93.7652%     14.7977s
# (464,)               93.8057%     14.7158s
# (456,)               93.7652%     14.5692s
# (448,)               93.6842%     14.3969s
# (440,)               93.5628%     14.2381s
# (432,)               93.5223%     13.9428s
# (424,)               93.6032%     14.0046s
# (416,)               93.6032%     13.6727s
# (408,)               93.5628%     13.5728s
# (400,)               93.6032%     13.3905s
# (392,)               93.5223%     13.0533s
# (384,)               93.4008%     12.8413s
# (376,)               93.2794%     12.4153s
# (368,)               93.2794%     12.0985s
# (360,)               93.2389%     11.9688s
# (352,)               93.1579%     11.7205s
# (344,)               92.9555%     11.5171s
# (336,)               92.8745%     11.3801s
# (328,)               92.8745%     11.1568s
# (320,)               92.7126%     10.8814s
# (312,)               92.5911%     10.7416s
# (304,)               92.3887%     10.5377s
# (296,)               92.5506%     10.4184s
# (288,)               93.0769%     10.1855s
# (280,)               93.1579%      9.9632s
# (272,)               92.9555%      9.7931s
# (264,)               93.0364%      9.5435s
# (256,)               92.7935%      9.3839s
# (248,)               92.8745%      9.1377s
# (240,)               92.5911%      8.9192s
# (232,)               92.4291%      8.5756s
# (224,)               92.2267%      8.5350s
# (216,)               91.9838%      8.1986s
# (208,)               91.8623%      7.9734s
# (200,)               91.7409%      7.6921s
# (192,)               91.5789%      7.4458s
# (184,)               91.3765%      7.2308s
# (176,)               91.0526%      6.9511s
# (168,)               90.8502%      6.8448s
# (160,)               90.6073%      6.6011s
# (152,)               90.0810%      6.3164s
# (144,)               89.6356%      6.1132s
# (136,)               89.5547%      5.8922s
# (128,)               88.7854%      5.7095s
# (120,)               88.3806%      5.4877s
# (112,)               87.8543%      5.1778s
# (104,)               86.5587%      5.0233s
# (96,)                84.9798%      4.8325s
# (88,)                83.1579%      4.5491s
# (80,)                80.5263%      4.3103s
# (72,)                76.8826%      4.1680s
# (64,)                78.4211%      3.8344s
# (56,)                71.7814%      3.6586s
# (48,)                62.7126%      3.4405s
# (40,)                50.6478%      3.2009s
# (32,)                39.5547%      3.0131s
# (16,)                6.5587%      2.6951s

# %%
print(f"{'Start dim, Max dim, K':<20} {'Accuracy %':<10} {'Median Time (s)':<15}")

for k, v in progressive_trunc_knn.items():
    print(f"{str(k):<20} {v['accuracy_pct']:7.4f}%    {v['median_time_s']:8.4f}s")
# Out:
# Start dim, Max dim, K Accuracy % Median Time (s)
# (64, 128, 4)         83.7247%      4.0400s
# (64, 128, 8)         85.2227%      4.0700s
# (64, 128, 16)        86.4372%      4.2900s
# (64, 128, 32)        87.2470%      4.7500s
# (64, 128, 64)        87.8947%      5.4750s
# (64, 128, 128)       88.5020%      6.5100s
# (64, 128, 256)       88.5830%      8.1050s
# (64, 128, 512)       88.7449%      9.3450s
# (64, 128, 1024)      88.7449%     12.9950s
# (64, 256, 4)         84.8178%      4.0400s
# (64, 256, 8)         86.6397%      4.2300s
# (64, 256, 16)        88.4211%      4.5100s
# (64, 256, 32)        89.7571%      5.1400s
# (64, 256, 64)        90.5263%      6.1900s
# (64, 256, 128)       91.5385%      7.8300s
# (64, 256, 256)       91.9838%     10.6550s
# (64, 256, 512)       92.4696%     14.5950s
# (64, 256, 1024)      92.6721%     19.9400s
# (64, 512, 4)         84.8178%      4.1100s
# (64, 512, 8)         86.8016%      4.3100s
# (64, 512, 16)        88.7854%      4.7200s
# (64, 512, 32)        90.1215%      5.6050s
# (64, 512, 64)        91.0526%      7.0500s
# (64, 512, 128)       92.1457%      9.3600s
# (64, 512, 256)       92.7126%     13.2100s
# (64, 512, 512)       93.3198%     19.0400s
# (64, 512, 1024)      93.5628%     27.2100s
# (64, 1024, 4)        84.8178%      4.3900s
# (64, 1024, 8)        86.8016%      4.5950s
# (64, 1024, 16)       89.1498%      5.0850s
# (64, 1024, 32)       90.5263%      6.0150s
# (64, 1024, 64)       91.4980%      7.8200s
# (64, 1024, 128)      92.6316%     10.4950s
# (64, 1024, 256)      93.2794%     13.9150s
# (64, 1024, 512)      93.9271%     20.7600s
# (64, 1024, 1024)     94.2105%     33.7250s
# (64, 2048, 4)        84.8178%      4.3950s
# (64, 2048, 8)        86.8016%      4.6350s
# (64, 2048, 16)       89.1498%      4.9350s
# (64, 2048, 32)       90.7287%      5.9750s
# (64, 2048, 64)       91.7409%      7.6900s
# (64, 2048, 128)      92.7935%     10.7350s
# (64, 2048, 256)      93.5223%     17.3600s
# (64, 2048, 512)      94.2105%     25.1650s
# (64, 2048, 1024)     94.6154%     42.1350s
# (64, 3584, 4)        84.8178%      4.6600s
# (64, 3584, 8)        86.8016%      4.9200s
# (64, 3584, 16)       89.1498%      5.4100s
# (64, 3584, 32)       90.7287%      6.4900s
# (64, 3584, 64)       91.7409%      8.6900s
# (64, 3584, 128)      92.8340%     12.6750s
# (64, 3584, 256)      93.6032%     19.0250s
# (64, 3584, 512)      94.3320%     31.1700s
# (64, 3584, 1024)     94.7368%     49.7600s
# (128, 256, 4)        92.2267%      5.8150s
# (128, 256, 8)        92.3077%      5.9300s
# (128, 256, 16)       92.5506%      6.2250s
# (128, 256, 32)       92.5911%      6.5500s
# (128, 256, 64)       92.6721%      7.5250s
# (128, 256, 128)      92.7935%      8.9350s
# (128, 256, 256)      92.7935%     10.8250s
# (128, 256, 512)      92.7935%     13.4050s
# (128, 256, 1024)     92.7935%     16.5750s
# (128, 512, 4)        92.3077%      6.0600s
# (128, 512, 8)        92.7126%      6.2600s
# (128, 512, 16)       93.1174%      6.7250s
# (128, 512, 32)       93.4008%      7.5500s
# (128, 512, 64)       93.4818%      9.0900s
# (128, 512, 128)      93.6437%     11.6150s
# (128, 512, 256)      93.7652%     15.7900s
# (128, 512, 512)      93.7652%     21.7100s
# (128, 512, 1024)     93.7652%     28.3500s
# (128, 1024, 4)       92.3077%      6.1500s
# (128, 1024, 8)       93.2389%      6.4400s
# (128, 1024, 16)      93.6437%      7.1250s
# (128, 1024, 32)      93.9676%      8.3850s
# (128, 1024, 64)      94.0486%     10.4350s
# (128, 1024, 128)     94.2915%     14.2150s
# (128, 1024, 256)     94.4130%     20.3950s
# (128, 1024, 512)     94.4130%     29.4300s
# (128, 1024, 1024)    94.4534%     41.8250s
# (128, 2048, 4)       92.3077%      6.2500s
# (128, 2048, 8)       93.2389%      6.5600s
# (128, 2048, 16)      93.8866%      7.3900s
# (128, 2048, 32)      94.2510%      8.8750s
# (128, 2048, 64)      94.4130%     11.5150s
# (128, 2048, 128)     94.6559%     16.4250s
# (128, 2048, 256)     94.8178%     24.3500s
# (128, 2048, 512)     94.8178%     35.1900s
# (128, 2048, 1024)    94.7773%     56.3350s
# (128, 3584, 4)       92.3077%      6.6100s
# (128, 3584, 8)       93.2389%      6.8650s
# (128, 3584, 16)      93.8866%      7.4500s
# (128, 3584, 32)      94.2915%      9.0550s
# (128, 3584, 64)      94.4939%     12.1750s
# (128, 3584, 128)     94.7368%     17.6500s
# (128, 3584, 256)     94.8988%     26.7950s
# (128, 3584, 512)     94.9393%     42.8600s
# (128, 3584, 1024)    94.9798%     66.9800s
# (256, 512, 4)        93.4818%      9.3250s
# (256, 512, 8)        93.6437%      9.5300s
# (256, 512, 16)       93.7247%     10.0050s
# (256, 512, 32)       93.7652%     10.7150s
# (256, 512, 64)       93.8057%     11.9800s
# (256, 512, 128)      93.8057%     14.4750s
# (256, 512, 256)      93.8057%     17.7500s
# (256, 512, 512)      93.8057%     23.0250s
# (256, 512, 1024)     93.8057%     27.9550s
# (256, 1024, 4)       94.1296%      9.8600s
# (256, 1024, 8)       94.3320%     10.3200s
# (256, 1024, 16)      94.3320%     11.0250s
# (256, 1024, 32)      94.4130%     12.5100s
# (256, 1024, 64)      94.4534%     15.1350s
# (256, 1024, 128)     94.4534%     19.6950s
# (256, 1024, 256)     94.4534%     27.0550s
# (256, 1024, 512)     94.4939%     36.9250s
# (256, 1024, 1024)    94.4939%     48.8900s
# (256, 2048, 4)       94.1296%      9.9650s
# (256, 2048, 8)       94.7368%     10.4800s
# (256, 2048, 16)      94.7368%     11.5950s
# (256, 2048, 32)      94.8178%     13.7850s
# (256, 2048, 64)      94.8583%     17.6700s
# (256, 2048, 128)     94.8178%     24.3400s
# (256, 2048, 256)     94.8178%     35.7850s
# (256, 2048, 512)     94.8178%     52.4400s
# (256, 2048, 1024)    94.8178%     75.4400s
# (256, 3584, 4)       94.1296%     10.1850s
# (256, 3584, 8)       94.7368%     10.7100s
# (256, 3584, 16)      94.8178%     12.1650s
# (256, 3584, 32)      94.9393%     14.6300s
# (256, 3584, 64)      94.9798%     19.1550s
# (256, 3584, 128)     94.9798%     27.5250s
# (256, 3584, 256)     94.9798%     41.9650s
# (256, 3584, 512)     95.0202%     65.3250s
# (256, 3584, 1024)    95.0202%     99.2700s
# (512, 1024, 4)       94.4939%     17.2400s
# (512, 1024, 8)       94.4939%     17.6500s
# (512, 1024, 16)      94.4939%     18.6300s
# (512, 1024, 32)      94.4939%     19.4250s
# (512, 1024, 64)      94.4939%     21.7550s
# (512, 1024, 128)     94.4939%     25.7100s
# (512, 1024, 256)     94.4939%     31.5300s
# (512, 1024, 512)     94.4939%     39.3500s
# (512, 1024, 1024)    94.4939%     47.1800s
# (512, 2048, 4)       94.8583%     17.6950s
# (512, 2048, 8)       94.8583%     18.3000s
# (512, 2048, 16)      94.8988%     19.8100s
# (512, 2048, 32)      94.8583%     22.2450s
# (512, 2048, 64)      94.8583%     26.9700s
# (512, 2048, 128)     94.8583%     34.8550s
# (512, 2048, 256)     94.8178%     47.0400s
# (512, 2048, 512)     94.8178%     65.8800s
# (512, 2048, 1024)    94.8178%     92.9300s
# (512, 3584, 4)       94.8583%     18.0950s
# (512, 3584, 8)       94.9393%     18.8050s
# (512, 3584, 16)      95.0202%     20.6300s
# (512, 3584, 32)      95.0202%     24.1600s
# (512, 3584, 64)      95.0202%     30.6300s
# (512, 3584, 128)     95.0202%     42.4900s
# (512, 3584, 256)     95.0202%     62.0700s
# (512, 3584, 512)     95.0202%     95.4050s
# (512, 3584, 1024)    95.0202%    135.4550s
# (1024, 2048, 4)      94.8583%     31.2200s
# (1024, 2048, 8)      94.8583%     31.9000s
# (1024, 2048, 16)     94.8583%     32.5550s
# (1024, 2048, 32)     94.8583%     35.1300s
# (1024, 2048, 64)     94.8583%     39.3450s
# (1024, 2048, 128)    94.8178%     46.6600s
# (1024, 2048, 256)    94.8178%     57.8500s
# (1024, 2048, 512)    94.8178%     71.3000s
# (1024, 2048, 1024)   94.8178%     84.7350s
# (1024, 3584, 4)      94.9798%     31.4450s
# (1024, 3584, 8)      95.0202%     32.3550s
# (1024, 3584, 16)     95.0202%     35.2950s
# (1024, 3584, 32)     95.0202%     40.0800s
# (1024, 3584, 64)     95.0202%     48.2700s
# (1024, 3584, 128)    95.0202%     63.3150s
# (1024, 3584, 256)    95.0202%     84.5450s
# (1024, 3584, 512)    95.0202%    115.0250s
# (1024, 3584, 1024)   95.0202%    150.8050s
# (2048, 3584, 4)      95.0202%     58.8750s
# (2048, 3584, 8)      95.0202%     59.8500s
# (2048, 3584, 16)     95.0202%     62.0150s
# (2048, 3584, 32)     95.0202%     66.1350s
# (2048, 3584, 64)     95.0202%     73.2850s
# (2048, 3584, 128)    95.0202%     86.0850s
# (2048, 3584, 256)    95.0202%    104.9600s
# (2048, 3584, 512)    95.0202%    133.5700s
# (2048, 3584, 1024)   95.0202%    155.9250s

# %%
import csv

with open(f"{drive_root}/static_truncate_knn.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Key", "Accuracy (%)", "Median Time (s)"])

    for k, v in original_trunc_knn.items():
        key_str = ", ".join(map(str, k))
        writer.writerow([key_str, f"{v['accuracy_pct']:.4f}", f"{v['median_time_s']:.4f}"])

# %%
with open(f"{drive_root}/progressive_truncate_knn.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Starting Dim", "Max Dim", "Top K", "Accuracy (%)", "Median Time (s)"])

    for k, v in progressive_trunc_knn.items():
        # Unpack the tuple into parts
        starting_dim, max_dim, top_k = k

        accuracy = f"{v['accuracy_pct']:.4f}"
        time = f"{v['median_time_s']:.4f}"

        # Write them separately
        writer.writerow([starting_dim, max_dim, top_k, accuracy, time])
